# %%
import json
from tqdm.notebook import tqdm
import psycopg2
import psycopg2.extras
from pprint import pprint
import datetime
from numpy import interp
from matplotlib import pyplot
import pandas as pd
import pandas.io.sql as sqlio
from pandas.plotting import scatter_matrix
from matplotlib.pyplot import figure
import copy
import matplotlib.pyplot as plt
import collections

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import export_graphviz

# %%
def resultsAsDictArray(results, colnames):
    return_array = []
    for result in tqdm(results):
        d = {}
        for col in colnames:
            d[col] = result[colnames.index(col)]
        return_array.append(d)
    return return_array

# %%
conn = psycopg2.connect(user='postgres', database="postgres", password='password', host='localhost', port='5432')
cursor = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %%
cursor.execute('SELECT * FROM music')
results = cursor.fetchall()
colnames = [desc[0] for desc in cursor.description]
musics = resultsAsDictArray(results, colnames)
# Out:
#   0%|          | 0/697510 [00:00<?, ?it/s]

# %%
cursor.execute('SELECT * FROM music_artist')
results = cursor.fetchall()
colnames = [desc[0] for desc in cursor.description]
musics_artists_raw = resultsAsDictArray(results, colnames)
# Out:
#   0%|          | 0/1127195 [00:00<?, ?it/s]

# %%
musics_artists = {}
for music_artist in musics_artists_raw:
    music_id = music_artist['music_id']
    if music_id not in musics_artists:
        musics_artists[music_id] = []
    musics_artists[music_id].append(music_artist['artist_id'])

# %%
cursor.execute("""
SELECT * 
FROM artist a 
INNER JOIN genre_artist ga ON a.artist_id = ga.artist_id
INNER JOIN genre g ON g.genre_id = ga.genre_id
INNER JOIN genre_category gc ON gc.genre_id = g.genre_id
INNER JOIN category c ON c.category_id = gc.category_id
""")
results = cursor.fetchall()
colnames = [desc[0] for desc in cursor.description]
artists_raw = resultsAsDictArray(results, colnames)
# Out:
#   0%|          | 0/12574 [00:00<?, ?it/s]

# %%
artists_multiple = {}
for artist in artists_raw:
    artist_id = artist['artist_id']
    if artist_id not in artists_multiple:
        artists_multiple[artist_id] = []
    artists_multiple[artist_id].append(artist)
#     pprint(artist)
#     break

# %%
artists = {}
for artist in tqdm(artists_multiple):
    for i in artists_multiple[artist]:
        if i['artist_id'] not in artists:
            artists[i['artist_id']] = copy.deepcopy(i)
            artists[i['artist_id']]['genres'] = set()
            artists[i['artist_id']]['categories'] = set()
            artists[i['artist_id']].pop('category_id', None)
            artists[i['artist_id']].pop('category', None)
            artists[i['artist_id']].pop('genre_artist_id', None)
            artists[i['artist_id']].pop('genre_category_id', None)
            artists[i['artist_id']].pop('genre_id', None)
            artists[i['artist_id']].pop('genre', None)
        artists[i['artist_id']]['genres'].add(i['genre'])
        artists[i['artist_id']]['categories'].add(i['category'])
#     pprint(artists)
#     break
# Out:
#   0%|          | 0/3380 [00:00<?, ?it/s]

# %%
cursor.execute('SELECT * FROM category')
results = cursor.fetchall()
colnames = [desc[0] for desc in cursor.description]
categories = resultsAsDictArray(results, colnames)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
cursor.execute('SELECT * FROM genre')
results = cursor.fetchall()
colnames = [desc[0] for desc in cursor.description]
genres = resultsAsDictArray(results, colnames)
# Out:
#   0%|          | 0/1583 [00:00<?, ?it/s]

# %%
for music in musics:
    music_id = music['music_id']
    for category in categories:
        music[category['category']] = 0
    list_artist = []
    for music_artist in musics_artists.get(music_id, []):
        artist = artists.get(music_artist, '')
        if artist == '':
            continue
        for category in list(artist['categories']):
            music[category] = 1
        music['genres'] = ', '.join(list(artist['genres']))
        list_artist.append(artist['name'])
    music['artists'] = ', '.join(list_artist)
#     pprint(music)
#     break

# %% [markdown]
# ### Via Word2Vec

# %%
import nltk
import urllib
import bs4 as bs
import re
import numpy as np
from gensim.models import Word2Vec

# %%
genres_raw_words = set()
artists_raw_words = set()
for music in musics:
    text = music.get('genres', '').replace(',', '')
    if text != '':
        genres_raw_words.add(text)
        
    text = music.get('artists', '').replace(',', '').lower()
    text = re.sub(r'\W+', ' ', text)
    if text != '':
        artists_raw_words.add(text)

# %%
sentences_genres = [nltk.word_tokenize(sentence) for sentence in genres_raw_words]
model_genres = Word2Vec(sentences_genres, min_count=1)

sentences_artists = [nltk.word_tokenize(sentence) for sentence in artists_raw_words]
model_artists = Word2Vec(sentences_artists, min_count=1)

# %%
# similar = model_genres.wv.most_similar('indie')
# similar

# %%
similar = model_artists.wv.most_similar('sia')
similar
# Out:
# [('bruno', 0.9938116669654846),
#  ('smith', 0.9936599731445312),
#  ('emicida', 0.9934771656990051),
#  ('diplo', 0.9933702349662781),
#  ('mc', 0.9933419227600098),
#  ('jorge', 0.9933387041091919),
#  ('max', 0.9930333495140076),
#  ('r3hab', 0.9929155707359314),
#  ('santana', 0.9928524494171143),
#  ('eric', 0.9928420186042786)]

# %%
np.mean(np.mean([model_artists.wv[token] for token in nltk.word_tokenize('sia')], axis=0))
# Out:
# -0.002232366

# %%
for music in tqdm(musics):
    text = music.get('genres', '').replace(',', '')
    if text != '':
        music['genres_emb'] = np.mean(np.mean([model_genres.wv[token] for token in nltk.word_tokenize(text)], axis=0))
        
    text = music.get('artists', '').replace(',', '').lower()
    text = re.sub(r'\W+', ' ', text)
    if text != '':
        music['artists_emb'] = np.mean(np.mean([model_artists.wv[token] for token in nltk.word_tokenize(text)], axis=0))
# Out:
#   0%|          | 0/697510 [00:00<?, ?it/s]

# %%
pprint(music)
# Out:
# {'Blues': 0,
#  'Classical': 0,
#  'Country': 0,
#  'Edm': 0,
#  'Folk': 0,
#  'Funk': 0,
#  'Hip hop': 1,
#  'Indie': 0,
#  'Instrumental': 0,
#  'Jazz': 0,
#  'Lo-fi': 0,
#  'Metal': 0,
#  'Nacional': 0,
#  'Pop': 1,
#  'Punk': 0,
#  'R&b': 0,
#  'Rap': 1,
#  'Reggae': 0,
#  'Rock': 0,
#  'Sertanejo': 0,
#  'Soundtrack': 0,
#  'acousticness': 0.162,
#  'artists': 'Mike Posner, Big Sean',
#  'artists_emb': 0.0009453584,
#  'danceability': 0.653,
#  'duration_ms': 203346.0,
#  'energy': 0.661,
#  'genres': 'rap, hip hop, southern hip hop, detroit hip hop, trap, pop rap',
#  'genres_emb': 0.012812643,
#  'instrumentalness': 1.46e-06,
#  'like_rate': None,
#  'liveness': 0.394,
#  'loudness': -8.036,
#  'mode': 0,
#  'music_id': 8039,
#  'music_key': 7,
#  'music_spotify_uri': 'spotify:track:3wxSjRp3mrsr4vaF1VSH4U',
#  'name': 'Buried In Detroit - Lucas Löwe Remix',
#  'popularity': 0,
#  'speechiness': 0.0371,
#  'tempo': 102.962,
#  'time_signature': 4.0,
#  'valence': 0.65}

# %% [markdown]
# # Train Model

# %%
df = pd.DataFrame.from_records(musics)

# %%
# Eram 697510 rows × 36 columns
df_filtered = df.drop(columns=['name', 'duration_ms', 'mode', 'time_signature', 'genres', 'artists'])
df_filtered = df_filtered[df_filtered['genres_emb'].notna()]
df_filtered = df_filtered[df_filtered['artists_emb'].notna()]

df_filtered.insert(2, 'like_rate_temp', df_filtered['like_rate'])
df_filtered.drop('like_rate', axis=1, inplace=True) 
df_filtered.rename(columns={'like_rate_temp': 'like_rate'}, inplace=True)

df_filtered = df_filtered.reset_index()
df_filtered = df_filtered.drop(columns=['index'])



df_filtered
# Out:
#         music_id                     music_spotify_uri  like_rate  popularity  \
# 0           8040  spotify:track:0awxPw2WkYJVzcSKWvJZAh        NaN        45.0
# 1           8041  spotify:track:4ToSbnK7fD5vE9R5sgWPsy        NaN         0.0
# 2           8042  spotify:track:5GW2n1h3BNYnpU7lK23iKv        NaN         0.0
# 3           8043  spotify:track:3M0pROlXyH0bzh9CNJhDOJ        NaN         0.0
# 4           8044  spotify:track:1uGAMOMKqPPYxAllZ1PV4s        NaN         0.0
# ...          ...                                   ...        ...         ...
# 532621      8035  spotify:track:3Z9Kaszz1KKOdWhP7Q8fVR        NaN         0.0
# 532622      8036  spotify:track:20FREPNcSl4TnZEt1GAYSB        NaN         0.0
# 532623      8037  spotify:track:47uRsTBT1Jb93QSvY5C12O        NaN         0.0
# 532624      8038  spotify:track:6vzhxMkDnTdRURQzqI1p0L        NaN         0.0
# 532625      8039  spotify:track:3wxSjRp3mrsr4vaF1VSH4U        NaN         0.0
#
#         danceability    energy  music_key  loudness  speechiness  \
# 0              0.631  0.534000        2.0    -6.783       0.0848
# 1              0.536  0.762000        8.0    -6.749       0.0427
# 2              0.695  0.705000        7.0    -5.493       0.0243
# 3              0.656  0.572000        4.0    -8.162       0.0319
# 4              0.696  0.417000        9.0    -9.624       0.0270
# ...              ...       ...        ...       ...          ...
# 532621         0.000  0.000278        5.0   -32.668       0.0000
# 532622         0.717  0.807000        8.0    -8.348       0.0632
# 532623         0.670  0.685000        2.0    -5.486       0.0510
# 532624         0.814  0.642000        0.0    -6.394       0.0951
# 532625         0.653  0.661000        7.0    -8.036       0.0371
#
#         acousticness  ...  Funk  Soundtrack  Punk  Country  Classical  \
# 0             0.5050  ...     0           0     0        0          0
# 1             0.2700  ...     0           0     0        0          0
# 2             0.3140  ...     0           0     0        0          0
# 3             0.6530  ...     0           0     0        0          0
# 4             0.8260  ...     0           0     0        0          0
# ...              ...  ...   ...         ...   ...      ...        ...
# 532621        0.0219  ...     0           0     0        0          0
# 532622        0.0912  ...     0           0     0        0          0
# 532623        0.0625  ...     0           0     0        0          0
# 532624        0.1320  ...     0           0     0        0          0
# 532625        0.1620  ...     0           0     0        0          0
#
#         Instrumental  Sertanejo  Lo-fi  genres_emb  artists_emb
# 0                  0          0      0    0.014622    -0.001097
# 1                  0          0      0    0.011400    -0.001744
# 2                  0          0      0    0.011400    -0.001744
# 3                  0          0      0    0.011400    -0.001744
# 4                  0          0      0    0.011400    -0.001744
# ...              ...        ...    ...         ...          ...
# 532621             0          0      0    0.016600    -0.002409
# 532622             0          0      0    0.016600    -0.002409
# 532623             0          0      0    0.016600    -0.002409
# 532624             0          0      0    0.016600    -0.002409
# 532625             0          0      0    0.012813     0.000945
#
# [532626 rows x 37 columns]

# %%
df_train = df_filtered[df_filtered['like_rate'].notna()]
df_train['like_rate'][df_train['like_rate'] > 0.35] = 1
df_train['like_rate'][df_train['like_rate'] <= 0.35] = 0
df_train
# Out:
# C:\Users\MATHEU~1\AppData\Local\Temp/ipykernel_8684/710602685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['like_rate'][df_train['like_rate'] > 0.35] = 1
# c:\dev\miniconda3\lib\site-packages\pandas\core\generic.py:8861: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# C:\Users\MATHEU~1\AppData\Local\Temp/ipykernel_8684/710602685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['like_rate'][df_train['like_rate'] <= 0.35] = 0
#         music_id                     music_spotify_uri  like_rate  popularity  \
# 525611      6114  spotify:track:0Mh4id8WvrTFOB9RiVitrB        0.0         0.0
# 525612      4790  spotify:track:4JAbD641MOEYu8bP81rtIG        0.0         0.0
# 525613       273  spotify:track:6u7jPi22kF8CTQ3rb9DHE7        1.0         7.0
# 525614      5761  spotify:track:45sziCSqS4BWSQWUlLRpyf        0.0        55.0
# 525615      7662  spotify:track:3lwp8aybnEo8OaO0hzQD0C        0.0        24.0
# ...          ...                                   ...        ...         ...
# 532451        19  spotify:track:7pYFPMeK0TnaTGdS6qOtEr        0.0        59.0
# 532452         2  spotify:track:5jjZikDrEd0by1o7V3fO4y        1.0        73.0
# 532453         9  spotify:track:54KFQB6N4pn926IUUYZGzK        1.0        72.0
# 532454         1  spotify:track:1TDk2Jmi4dVZhm2dum3Jim        0.0        66.0
# 532455        11  spotify:track:5JweKVLG4RMiA9swuKW3mg        0.0        22.0
#
#         danceability  energy  music_key  loudness  speechiness  acousticness  \
# 525611         0.758   0.500        1.0    -6.810       0.4370      0.364000
# 525612         0.548   0.879       11.0    -4.120       0.0478      0.019100
# 525613         0.878   0.619        6.0    -5.560       0.1020      0.053300
# 525614         0.439   0.908        4.0    -4.080       0.0644      0.019600
# 525615         0.204   0.337        2.0   -12.595       0.0363      0.827000
# ...              ...     ...        ...       ...          ...           ...
# 532451         0.372   0.919       11.0    -1.680       0.3000      0.098700
# 532452         0.804   0.323        0.0   -11.127       0.3050      0.308000
# 532453         0.264   0.122        9.0   -15.399       0.0349      0.885000
# 532454         0.452   0.873        9.0    -4.867       0.0613      0.000519
# 532455         0.428   0.333        8.0   -12.890       0.0445      0.928000
#
#         ...  Funk  Soundtrack  Punk  Country  Classical  Instrumental  \
# 525611  ...     0           0     0        0          0             0
# 525612  ...     0           0     0        0          0             0
# 525613  ...     0           0     0        1          0             0
# 525614  ...     0           0     0        0          0             0
# 525615  ...     0           0     0        0          1             0
# ...     ...   ...         ...   ...      ...        ...           ...
# 532451  ...     0           0     0        0          0             0
# 532452  ...     0           0     0        0          0             0
# 532453  ...     0           0     0        0          0             0
# 532454  ...     0           0     0        0          0             0
# 532455  ...     0           0     0        0          0             0
#
#         Sertanejo  Lo-fi  genres_emb  artists_emb
# 525611          0      0    0.012000    -0.000080
# 525612          0      0    0.015219    -0.001444
# 525613          0      0    0.015006    -0.000421
# 525614          0      0    0.013844     0.000686
# 525615          0      0    0.007530     0.001817
# ...           ...    ...         ...          ...
# 532451          0      0    0.015497    -0.000654
# 532452          0      0    0.013614    -0.000869
# 532453          0      0    0.015142     0.000424
# 532454          0      0    0.013934     0.000167
# 532455          0      0    0.013934    -0.000603
#
# [6703 rows x 37 columns]

# %%
array = df_train.values
X = array[:,3:]
y = array[:,2]
y = y.astype('int')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
dtc = DecisionTreeClassifier(random_state=42)
dtc.fit(X_train, y_train)
dtc.score(X_test, y_test)
# Out:
# 0.7434112381899552

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_features=10, random_state=42, max_leaf_nodes=150, max_depth=7, min_samples_split=100)
dtc.fit(X_train, y_train)
dtc.score(X_test, y_test)
# Out:
# 0.8125310790651418

# %%
bag = BaggingClassifier(dtc, n_estimators=100, max_samples=0.8, random_state=42)
bag.fit(X_train, y_train)
bag.score(X_test, y_test)
# Out:
# 0.8160119343610144

# %% [markdown]
# ## Try

# %%
df_try = df_filtered[df_filtered['like_rate'].isna()]
df_try = df_try.reset_index()
df_try = df_try.drop(columns=['index'])

df_try
# Out:
#         music_id                     music_spotify_uri  like_rate  popularity  \
# 0           8040  spotify:track:0awxPw2WkYJVzcSKWvJZAh        NaN        45.0
# 1           8041  spotify:track:4ToSbnK7fD5vE9R5sgWPsy        NaN         0.0
# 2           8042  spotify:track:5GW2n1h3BNYnpU7lK23iKv        NaN         0.0
# 3           8043  spotify:track:3M0pROlXyH0bzh9CNJhDOJ        NaN         0.0
# 4           8044  spotify:track:1uGAMOMKqPPYxAllZ1PV4s        NaN         0.0
# ...          ...                                   ...        ...         ...
# 525918      8035  spotify:track:3Z9Kaszz1KKOdWhP7Q8fVR        NaN         0.0
# 525919      8036  spotify:track:20FREPNcSl4TnZEt1GAYSB        NaN         0.0
# 525920      8037  spotify:track:47uRsTBT1Jb93QSvY5C12O        NaN         0.0
# 525921      8038  spotify:track:6vzhxMkDnTdRURQzqI1p0L        NaN         0.0
# 525922      8039  spotify:track:3wxSjRp3mrsr4vaF1VSH4U        NaN         0.0
#
#         danceability    energy  music_key  loudness  speechiness  \
# 0              0.631  0.534000        2.0    -6.783       0.0848
# 1              0.536  0.762000        8.0    -6.749       0.0427
# 2              0.695  0.705000        7.0    -5.493       0.0243
# 3              0.656  0.572000        4.0    -8.162       0.0319
# 4              0.696  0.417000        9.0    -9.624       0.0270
# ...              ...       ...        ...       ...          ...
# 525918         0.000  0.000278        5.0   -32.668       0.0000
# 525919         0.717  0.807000        8.0    -8.348       0.0632
# 525920         0.670  0.685000        2.0    -5.486       0.0510
# 525921         0.814  0.642000        0.0    -6.394       0.0951
# 525922         0.653  0.661000        7.0    -8.036       0.0371
#
#         acousticness  ...  Funk  Soundtrack  Punk  Country  Classical  \
# 0             0.5050  ...     0           0     0        0          0
# 1             0.2700  ...     0           0     0        0          0
# 2             0.3140  ...     0           0     0        0          0
# 3             0.6530  ...     0           0     0        0          0
# 4             0.8260  ...     0           0     0        0          0
# ...              ...  ...   ...         ...   ...      ...        ...
# 525918        0.0219  ...     0           0     0        0          0
# 525919        0.0912  ...     0           0     0        0          0
# 525920        0.0625  ...     0           0     0        0          0
# 525921        0.1320  ...     0           0     0        0          0
# 525922        0.1620  ...     0           0     0        0          0
#
#         Instrumental  Sertanejo  Lo-fi  genres_emb  artists_emb
# 0                  0          0      0    0.014622    -0.001097
# 1                  0          0      0    0.011400    -0.001744
# 2                  0          0      0    0.011400    -0.001744
# 3                  0          0      0    0.011400    -0.001744
# 4                  0          0      0    0.011400    -0.001744
# ...              ...        ...    ...         ...          ...
# 525918             0          0      0    0.016600    -0.002409
# 525919             0          0      0    0.016600    -0.002409
# 525920             0          0      0    0.016600    -0.002409
# 525921             0          0      0    0.016600    -0.002409
# 525922             0          0      0    0.012813     0.000945
#
# [525923 rows x 37 columns]

# %%
array = df_try.values
X = array[:,3:]

# %%
music_note = {}
for i in tqdm(range(0, len(X), 1000)):
    max_i = i + 1000
    if max_i >= len(X):
        max_i = len(X) - 2
    predicted = bag.predict(X[i:max_i])
    for index, value in enumerate(predicted):
        music_note[df_try.loc[i + index]['music_spotify_uri']] = value
# Out:
#   0%|          | 0/526 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MATHEU~1\AppData\Local\Temp/ipykernel_8684/435832963.py in <module>
#       4     if max_i >= len(X):
#       5         max_i = len(X) - 2
# ----> 6     predicted = bag.predict(X[i:max_i])
#       7     for index, value in enumerate(predicted):
#       8         music_note[df_try.loc[i + index]['music_spotify_uri']] = value
#
# c:\dev\miniconda3\lib\site-packages\sklearn\ensemble\_bagging.py in predict(self, X)
#     675             The predicted classes.
#     676         """
# --> 677         predicted_probabilitiy = self.predict_proba(X)
#     678         return self.classes_.take((np.argmax(predicted_probabilitiy, axis=1)),
#     679                                   axis=0)
#
# c:\dev\miniconda3\lib\site-packages\sklearn\ensemble\_bagging.py in predict_proba(self, X)
#     718                                                              self.n_jobs)
#     719
# --> 720         all_proba = Parallel(n_jobs=n_jobs, verbose=self.verbose,
#     721                              **self._parallel_args())(
#     722             delayed(_parallel_predict_proba)(
#
# c:\dev\miniconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# c:\dev\miniconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# c:\dev\miniconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# c:\dev\miniconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\dev\miniconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\dev\miniconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\dev\miniconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\dev\miniconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# c:\dev\miniconda3\lib\site-packages\sklearn\ensemble\_bagging.py in _parallel_predict_proba(estimators, estimators_features, X, n_classes)
#     127     for estimator, features in zip(estimators, estimators_features):
#     128         if hasattr(estimator, "predict_proba"):
# --> 129             proba_estimator = estimator.predict_proba(X[:, features])
#     130
#     131             if n_classes == len(estimator.classes_):
#
# c:\dev\miniconda3\lib\site-packages\sklearn\tree\_classes.py in predict_proba(self, X, check_input)
#     933         """
#     934         check_is_fitted(self)
# --> 935         X = self._validate_X_predict(X, check_input)
#     936         proba = self.tree_.predict(X)
#     937
#
# c:\dev\miniconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     405         """Validate the training data on predict (probabilities)."""
#     406         if check_input:
# --> 407             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
#     408                                     reset=False)
#     409             if issparse(X) and (X.indices.dtype != np.intc or
#
# c:\dev\miniconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# c:\dev\miniconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\dev\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718
#     719         if force_all_finite:
# --> 720             _assert_all_finite(array,
#     721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#
# c:\dev\miniconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
music_note_sorted = dict(sorted(music_note.items(), key=lambda item: item[1], reverse=True))

# %%
_ = plt.hist(music_note_sorted.values(), bins='auto')

# %%
collections.Counter(music_note_sorted.values())
# Out:
# Counter({1: 18, 0: 524982})

# %%
music_note_sorted
# Out:
# {'spotify:track:0JKVKU80Hifd9A8lQKi9lc': 1,
#  'spotify:track:71nJDkBdbSNBVuw6TC9B5v': 1,
#  'spotify:track:5ZUObJNpVt2l9GogUSfALc': 1,
#  'spotify:track:14zduMrtXG6iAyoozpQhDA': 1,
#  'spotify:track:4PxTFojApbNeeIwiEEx2QX': 1,
#  'spotify:track:0s3kijZb80brcA2cdppjBZ': 1,
#  'spotify:track:1p9G2aRIbIPQGVXeJgLE4Z': 1,
#  'spotify:track:41OAXzXCrDCzRSlD1IBWtP': 1,
#  'spotify:track:2wbkovH4lLaiaFOceX1YAr': 1,
#  'spotify:track:66rU4Dff6qFAhia56xRs8E': 1,
#  'spotify:track:6mEpGxnTjoMdZQjo6UorbK': 1,
#  'spotify:track:70kJ2O6JiFg4nTATPw4b0E': 1,
#  'spotify:track:6oqlWkAUCqBXjvorIRSm54': 1,
#  'spotify:track:1Rzv9hwuNO1H7N947tD1e8': 1,
#  'spotify:track:03x5RegHjby0lwfcqQ2GjI': 1,
#  'spotify:track:2exUyljlhoH86MlcicuUXd': 1,
#  'spotify:track:25TrYuBFlgMIaaQDYZNJoa': 1,
#  'spotify:track:4fAWuHhfAqykApaqrR9tfK': 1,
#  'spotify:track:0awxPw2WkYJVzcSKWvJZAh': 0,
#  'spotify:track:4ToSbnK7fD5vE9R5sgWPsy': 0,
#  'spotify:track:5GW2n1h3BNYnpU7lK23iKv': 0,
#  'spotify:track:3M0pROlXyH0bzh9CNJhDOJ': 0,
#  'spotify:track:1uGAMOMKqPPYxAllZ1PV4s': 0,
#  'spotify:track:4ORCdEPIKuvJzegSSCrjQk': 0,
#  'spotify:track:0XiPojuM89Ox9F6OrQdeoJ': 0,
#  'spotify:track:1tHBYwDdPOE9BMPlMGoZIj': 0,
#  'spotify:track:7bhMycC0HMb6j652sblsKT': 0,
#  'spotify:track:01Q7stNowjtgqKSDK3MQHp': 0,
#  'spotify:track:4f7vxUNrB9BfsehXcJOiAc': 0,
#  'spotify:track:3KR5puUARG8vkKMtSCSn2n': 0,
#  'spotify:track:3VCGlrriSCQIAM9sXOIJOD': 0,
#  'spotify:track:2d7hyVntSlgXlyEZaWHvcB': 0,
#  'spotify:track:30fn2FXuh48yeWEqO4XeMt': 0,
#  'spotify:track:1Syx6JhcFKvbMVWLjFzUCQ': 0,
#  'spotify:track:4vug3wR43u0AhRH9D8Lp8t': 0,
#  'spotify:track:3Vj9SYcisXn7qmLrDe75k1': 0,
#  'spotify:track:6sSu6bHOIEe48kU7R3xj34': 0,
#  'spotify:track:3EVmPGTfyNycp7GKWTO16j': 0,
#  'spotify:track:2NxX2IORexAjAvuhHZw52u': 0,
#  'spotify:track:3Z0YN50RzRtmYre1bRG8H6': 0,
#  'spotify:track:3gd9jFyf2AhJPi1HqHUVFP': 0,
#  'spotify:track:1UKMN7B6qjo2JsQybKzv8e': 0,
#  'spotify:track:0trdnmxZLqJUEJGDTqu27t': 0,
#  'spotify:track:60AEGzxRNUQ3Pzg4tygzJC': 0,
#  'spotify:track:2wlKiUtEwCKbsQ5WZAwvDJ': 0,
#  'spotify:track:2hLUWy9FUautRQqbAQ66T9': 0,
#  'spotify:track:2LmwUKeGCJZUKHKwOrX3Xb': 0,
#  'spotify:track:05CNnC9ugYgnJgg6fIgyeQ': 0,
#  'spotify:track:0UvCh63URrLFcPkKt99hHd': 0,
#  'spotify:track:0zc2UcrURBMVTyV7J0wrAP': 0,
#  'spotify:track:24bxijgwUt0atHxfpHsH5A': 0,
#  'spotify:track:15J419FaKaBT7bYJmpLDpf': 0,
#  'spotify:track:6fnzVPHWtCxm4lxLyn5p4Q': 0,
#  'spotify:track:02ePjHjIiszSYqeLykvpTN': 0,
#  'spotify:track:0awZMpokrVSdvtYe1MdcWM': 0,
#  'spotify:track:3UUTUsYZAAAkcWgkoxHvcu': 0,
#  'spotify:track:1wo3UYTeizJHkwYIuLuBPF': 0,
#  'spotify:track:0nufhlacuDxP6rNm6qLNrc': 0,
#  'spotify:track:11JIdNpBagg6G0NHLDm2v2': 0,
#  'spotify:track:6BXJWKcfPtSxUJ4FOvCxjp': 0,
#  'spotify:track:2x4bx10t6R3ND7gQF2gOSy': 0,
#  'spotify:track:5SdSDvWHyaaMlDsrpWPKQV': 0,
#  'spotify:track:0E8QuZqZjKe7agk7xUr0PC': 0,
#  'spotify:track:73MtegmP7o1Gn2tBQIzIQk': 0,
#  'spotify:track:21I2d2zrIHJNPeaeGG5J3Y': 0,
#  'spotify:track:4VbvvkVr4i5ZDraIWH2z6W': 0,
#  'spotify:track:1fegDwyryqzBNk7e0xyNiu': 0,
#  'spotify:track:6Lcnoknad0SItzXiXUB1FF': 0,
#  'spotify:track:6d1Ic5JjnFCJ1mOISnGxA1': 0,
#  'spotify:track:2zxXXdJUeW8TW3Irt2yLcE': 0,
#  'spotify:track:1V9Pf732OdBhGg2ATDbr0g': 0,
#  'spotify:track:1QD9dSncDR1Re3TiYbIKgs': 0,
#  'spotify:track:3XrgFCMOtaR16jshPIYNmq': 0,
#  'spotify:track:0HJNNn9RfJYoCytDBxWCKk': 0,
#  'spotify:track:5xjnhYlZxNRbEy7MOb7zUa': 0,
#  'spotify:track:3YQUQqZFwBGJHECK9Wxxjj': 0,
#  'spotify:track:52hkRlethPWUQgo7oK18Bo': 0,
#  'spotify:track:4lZrwQ6IvEgEWik7X6AuK0': 0,
#  'spotify:track:43yfBfBRUM7N2GtxQg7HRm': 0,
#  'spotify:track:0Vwvv3Zu7giSWh7h5EAtr6': 0,
#  'spotify:track:585joDdqZv1e7un5dpVRAN': 0,
#  'spotify:track:36PN713KNBW3Yg06q0iqm3': 0,
#  'spotify:track:3HUTl3dLwwz9pufuRYko0K': 0,
#  'spotify:track:2ShpxEbp7wLgfoYpcXpu7x': 0,
#  'spotify:track:1EZZMBM7RkFDvd9Uk0ftLP': 0,
#  'spotify:track:1u8hPl2tPFAi4ArBKxwBPS': 0,
#  'spotify:track:1Pk4BGCEwlTKgDhKNZUbRg': 0,
#  'spotify:track:1Jp3egueDGwbrgylNPws6F': 0,
#  'spotify:track:6yyZu4GqZ4u1WUY9EHy6Wj': 0,
#  'spotify:track:3ZLnlVXe06mavQFjD4PBR3': 0,
#  'spotify:track:29MOQfRQS4b7ptGsbbSRVi': 0,
#  'spotify:track:2i9q8CteBmpslOJeQdMGqA': 0,
#  'spotify:track:2UalvsKqlhHShfzYTV2LkT': 0,
#  'spotify:track:2E8MXBzwmLJPXzhqoziRRe': 0,
#  'spotify:track:3e1UBmb9i92xeCjwukljSc': 0,
#  'spotify:track:3edcgP9BqXAwdyhblIiASA': 0,
#  'spotify:track:31fsj6wSyLkOGVWDsJAsAF': 0,
#  'spotify:track:1SEzEo04ivkvN8x6rppuwD': 0,
#  'spotify:track:5hj8bVmhltSOVIXY9HNFi8': 0,
#  'spotify:track:7AzuAVNOs7yg0BozFJF09p': 0,
#  'spotify:track:4j5YzAphVCaOIgEWsenWlx': 0,
#  'spotify:track:3Jc0ABqhf9yMLn8bbAdmKX': 0,
#  'spotify:track:1FsH6OZCKLWbBgqj8JcCvO': 0,
#  'spotify:track:6aG3DqLoM4k30T8dq2ZVwh': 0,
#  'spotify:track:5taNdpAS5LspAntqnAeLHu': 0,
#  'spotify:track:0PUUdunTZuG7EdPbci3PrE': 0,
#  'spotify:track:0C4LtOHBnmnbMiCvNibNTu': 0,
#  'spotify:track:3x9U6rAQf8HQ0QKhDR8lEs': 0,
#  'spotify:track:3RwHm771f9ZQY1YJhXzIyr': 0,
#  'spotify:track:03TY9Tv4ELLny0j3ScInPt': 0,
#  'spotify:track:32eSrzU7NWMYHYlY0eOoIS': 0,
#  'spotify:track:4FffvdmLjA0xfqsmUJPKBh': 0,
#  'spotify:track:4xwPOyN9VgaTPehdsLiYul': 0,
#  'spotify:track:1W3OUPn3mZOFepibDdmgel': 0,
#  'spotify:track:12hltWJCyOA6RPgNNcXood': 0,
#  'spotify:track:6xrii0wWbAYsvcQkdhCnzr': 0,
#  'spotify:track:1ClFrQKter80gTUlnr3xzs': 0,
#  'spotify:track:721gk0XGo9ZlsW2n2NIPko': 0,
#  'spotify:track:5TgOqvnvUNmd1kciGvjyXC': 0,
#  'spotify:track:5ZFqYsgI09PaUbH5vkrufz': 0,
#  'spotify:track:4yUtuNuDH5hXh24UVBrUAN': 0,
#  'spotify:track:5TdRUo465NcC36DomkwGcd': 0,
#  'spotify:track:3GH22kQ3ONn8B9jg0CgxEO': 0,
#  'spotify:track:0lvZe6L959LRgDRCgmSS0L': 0,
#  'spotify:track:6YWlpMzlczlVLlFn7t9Bcl': 0,
#  'spotify:track:0Nk0WGJ0q9WAciS7mcpM4w': 0,
#  'spotify:track:060THwCc4Ihq5DVV5Sn4Oi': 0,
#  'spotify:track:2bna7SNhic548QqVaO4vah': 0,
#  'spotify:track:2fKDO6U8g5pi0HZqXZ4EF0': 0,
#  'spotify:track:5Os7GlnEV5o8oXZKmyeRF8': 0,
#  'spotify:track:1C0pkkU3nc772Ce6KV6RbI': 0,
#  'spotify:track:29Pi22CMFOWs4ebBjhG7ZH': 0,
#  'spotify:track:0kVspKnBcRkoPMbEzrmiav': 0,
#  'spotify:track:458gevlvVGu3MHNwiXmh3f': 0,
#  'spotify:track:0lOEOflAkoqLcgp0jqshcZ': 0,
#  'spotify:track:5iwIi2ZrRrRxzcQLVG70Rf': 0,
#  'spotify:track:5qmtkyOgqA2HhjWRHj5Gez': 0,
#  'spotify:track:5ssDVF6DwLv0z93CoxHgPZ': 0,
#  'spotify:track:2F1Ndgv2SMC2uwpyRTialz': 0,
#  'spotify:track:4wXPY2KSfzrYrIyz6Kp9G7': 0,
#  'spotify:track:5dAdCk6gynJA5fRSoRbbMM': 0,
#  'spotify:track:15MAxhNMTuaddCFWhIWJTA': 0,
#  'spotify:track:0ezYfia6TX5TpIPpI5U7MF': 0,
#  'spotify:track:0cuPs8UpeUcRqFfJl6kOnn': 0,
#  'spotify:track:37N3RcAgabwQkt8bng51nG': 0,
#  'spotify:track:5xcepqH2SKu8vxtpJHTFzG': 0,
#  'spotify:track:57WBal48ta4LBVDHylIafP': 0,
#  'spotify:track:3VXAZSjXG2ufroviooidVB': 0,
#  'spotify:track:7gAIXDtztINtrUvpPDVNgW': 0,
#  'spotify:track:14F5TWPFUXCD68fZwVD6T1': 0,
#  'spotify:track:7bdkrIrq1EEWHuHNO2MlGN': 0,
#  'spotify:track:36pBqy5EbRzQjemTRVs3TO': 0,
#  'spotify:track:7DL1uyJJ9j8kApbdkcL6p4': 0,
#  'spotify:track:6mAuw7R6u4vlNneuBgnC8K': 0,
#  'spotify:track:7brQHA2CgQpcMBiOlfiXYb': 0,
#  'spotify:track:0yyyapBjZ9Ek1vcpp3e9bj': 0,
#  'spotify:track:6cWpj6c5pNZYEk5KYjNBji': 0,
#  'spotify:track:4V37tyDu9CtqYshvrgLke4': 0,
#  'spotify:track:3vooOYHU0Fi3ViCG7Ozh0Y': 0,
#  'spotify:track:2Kt1XplPBQBsDKQDa6TssB': 0,
#  'spotify:track:4BDnfINTlfJPmLp1UV6CXt': 0,
#  'spotify:track:1NA2NvAgCB4EfcBC8OHfuj': 0,
#  'spotify:track:4MUvaBckjtNGlxX1IuHDPW': 0,
#  'spotify:track:00l9KCQeplWA4aGZWCyfes': 0,
#  'spotify:track:6e1sTwgUMyVxeHBiiTKHs9': 0,
#  'spotify:track:7G7mCFXQRHxNkbtsZPkNc9': 0,
#  'spotify:track:3ZRiCa1ROwlxKftO79ghJ1': 0,
#  'spotify:track:14sDzaqoSmpyqXkyaDDtyi': 0,
#  'spotify:track:59Sww77uD7VwyN0hlMKBWs': 0,
#  'spotify:track:5owH90gSdbZK9Iot4bCrjQ': 0,
#  'spotify:track:3pKRp4NX0YDl1bRANjJLSU': 0,
#  'spotify:track:2PhptzkiJ8kVQsO7tpRWLS': 0,
#  'spotify:track:3KhPDba7BR2uDM7tVep0dg': 0,
#  'spotify:track:1I7MQWuGQPxuEplPwEhj8i': 0,
#  'spotify:track:66XM8JXKr9A39wBMqIbytS': 0,
#  'spotify:track:3hZJ36jOs508nezkO740EM': 0,
#  'spotify:track:0IvBHyirLy7fLickwsqyA4': 0,
#  'spotify:track:6KpgqZwN6zen3qtOaz6rPl': 0,
#  'spotify:track:1p5dAU2s6kekj05gRVImTH': 0,
#  'spotify:track:2TPAS9lv9qceJT7o8oSNep': 0,
#  'spotify:track:3XBQciUm8idlYY3XoxlTiC': 0,
#  'spotify:track:7BjEZBsds3n6tN9KTEZpK4': 0,
#  'spotify:track:1xSEPN2WYdq8xrAXpCG9CO': 0,
#  'spotify:track:1ytmdDK5IqzTGhmEc4gHIt': 0,
#  'spotify:track:6Y5hGmficfyzKfSQtRpOch': 0,
#  'spotify:track:23LqDcaYel42gfSJ05tsC0': 0,
#  'spotify:track:4izlxzOjLPRzWy6Co5x0N0': 0,
#  'spotify:track:1hVanDiOYB9WLcRDbyo9xo': 0,
#  'spotify:track:00FWuEBvnitgpbMSk0XIoN': 0,
#  'spotify:track:2W8R0DqYzyHMe6DKYRKjSP': 0,
#  'spotify:track:6ZGoXOzTtHZCfKLUdypJp9': 0,
#  'spotify:track:2m7EWjTKCfNqrAdL1FSpd4': 0,
#  'spotify:track:504Ip38tLo9RbbSPIuThPB': 0,
#  'spotify:track:1TS55Vgmn2rwNvaNFP4ZTj': 0,
#  'spotify:track:6zkf9XiGqi7PXPMLrkyHWR': 0,
#  'spotify:track:52xOIchaCeR8r1S4iyRvY1': 0,
#  'spotify:track:3H0qlRXLI0R0B6HRZhoJTv': 0,
#  'spotify:track:5sLA16kNCBbGkx08ui3Z23': 0,
#  'spotify:track:0HmONWWIU1FXkwWLDpqrjl': 0,
#  'spotify:track:34F4GJFUzPvPJmGrTpyqlZ': 0,
#  'spotify:track:0RLjnX1vYWvtdThB8LABwo': 0,
#  'spotify:track:3gEkwDzAMiDMRsx5ivUqyj': 0,
#  'spotify:track:5G1wDrP7SO3Bu0dEeIPPk7': 0,
#  'spotify:track:7FKkVbJ9daWA5E1VE3OMFd': 0,
#  'spotify:track:5qmJ2IcaGvPNa4wpyzEglC': 0,
#  'spotify:track:3ewINnfCMmFwcG4VvlhgbU': 0,
#  'spotify:track:65ObdCmEa6SzJGvCdTXLUa': 0,
#  'spotify:track:09PXdHV9UTx8IdyC5RNyC8': 0,
#  'spotify:track:5lIxuwD7vdnijNeDBRX40N': 0,
#  'spotify:track:2FV7Ske1uYIC8StRYMkkRH': 0,
#  'spotify:track:6rFjY2BIff8jlNssd9nw9P': 0,
#  'spotify:track:0UKLrxOieGrkOrR9dojQ1u': 0,
#  'spotify:track:5UYYQuk6SjY3S892UuLXE3': 0,
#  'spotify:track:33MLUcVuAAVb36H7Ml32Bb': 0,
#  'spotify:track:6ldyzuBpCzLUX5y5p7CR46': 0,
#  'spotify:track:3w9mof4ZxG3z9huYwHFZ1i': 0,
#  'spotify:track:2CBtDxdTSz3MP8yUnA4Xkh': 0,
#  'spotify:track:3ZkUWF1MVm3tLgz7dplGpk': 0,
#  'spotify:track:22BH6K8RlpwNzIINvWS4Jj': 0,
#  'spotify:track:1t1xXsK199Yte7oJbE7Uoe': 0,
#  'spotify:track:7ExcclQypkEukgHqC40JNp': 0,
#  'spotify:track:7pJXKbp8Ls5SmMT3VutAnE': 0,
#  'spotify:track:0BmIb7qf0IIx9Lmvf6a28T': 0,
#  'spotify:track:17Sh8yP6z5fRzNyzD7SPyJ': 0,
#  'spotify:track:593Mcgv8wURGAJ3cvY9jqE': 0,
#  'spotify:track:1r5w2HnSiHcCR1c92UPOYU': 0,
#  'spotify:track:2oEHo5SYZqiDZdRH2ERNsD': 0,
#  'spotify:track:37AgQTDcQzUYPGVmwvAjdC': 0,
#  'spotify:track:3cPOyCp3luWrEQwWM3C5TK': 0,
#  'spotify:track:5HowM06CWtzijjo0vZxqmh': 0,
#  'spotify:track:3snOmtYV2IKiExIo0Umb1D': 0,
#  'spotify:track:6FzUX4kFBss56SSjAsLi7t': 0,
#  'spotify:track:2kxkMi5OctawcuFF2bzxCy': 0,
#  'spotify:track:0TOlQnrAuYW4ZgsNojhk57': 0,
#  'spotify:track:2ui7wDBgDddiHoEjGsUi6f': 0,
#  'spotify:track:5z0LZvYujGiAeZucn0N1n4': 0,
#  'spotify:track:5LPFxlca8oNgp8ywfOjT3f': 0,
#  'spotify:track:2MPYcy4FgkamwjJJNm6IVN': 0,
#  'spotify:track:7w7IUbBnLlhepsMsiRboSa': 0,
#  'spotify:track:1VZPSJinHNrUe2hMhAeklO': 0,
#  'spotify:track:2tPQ05EPYWZfy4oH8iVrQg': 0,
#  'spotify:track:3PbXibW2lq3fofpKHDtz2h': 0,
#  'spotify:track:689c685dK8S3V2sFnLAbwn': 0,
#  'spotify:track:6gxzPaizAhtKbyVGpfrqLK': 0,
#  'spotify:track:22LHIaxcDvOuBkKcKTM226': 0,
#  'spotify:track:6jl1qv57a4ECwKA6Z9lvrd': 0,
#  'spotify:track:0EcJECV2tbjNVZMBODjc2H': 0,
#  'spotify:track:2SaYfsGFzcUlkoneCcMRwE': 0,
#  'spotify:track:69oH0VS3z2DZWwo0IghP8f': 0,
#  'spotify:track:57Bj5CqhPC8vAT93jIRAXV': 0,
#  'spotify:track:6rzu2giczKfLfft0IjgcBf': 0,
#  'spotify:track:1foYfeVd8HVex402aOJN4o': 0,
#  'spotify:track:5Ttcj0dFKpTWbPbA8afWhS': 0,
#  'spotify:track:5B2KrwP88LtwuspnsGEOkn': 0,
#  'spotify:track:6Ct38LR16in3oqNoIq8k0V': 0,
#  'spotify:track:3yHsURe0ltdfD1NDDk5PWn': 0,
#  'spotify:track:3chN3fwZZDJO9LES2g0TDS': 0,
#  'spotify:track:2SOWmT6rFUSBLYoIvCgRif': 0,
#  'spotify:track:0qazt5sXx4rSzxBj7DHOhn': 0,
#  'spotify:track:0O8YMwF6fUty67k61XN9W7': 0,
#  'spotify:track:0fXS5YBrQo9jNTNnaRbnqk': 0,
#  'spotify:track:0nHFy6NhdXegDdokhXrTw0': 0,
#  'spotify:track:6N4xyXVJ8DMsVhOVxPd7p2': 0,
#  'spotify:track:1rEkvyg3rdnTvmhEASyQmg': 0,
#  'spotify:track:3BUnW43cyllWNWTPZxfcxZ': 0,
#  'spotify:track:3P19NoMAGg72XG22EOf4zm': 0,
#  'spotify:track:2emENw6ez73n0y0dM1Npeo': 0,
#  'spotify:track:0NdWASCRSWQzh7yeX5pczF': 0,
#  'spotify:track:1Hk87IqVU5Rr7iMHNZOFpN': 0,
#  'spotify:track:5T4XYHxzChkrYGZ4O84ioF': 0,
#  'spotify:track:4BDupPDVSeqG1YjDOn7pD6': 0,
#  'spotify:track:6ReF4Cn3aG4ehqC4NdrLrV': 0,
#  'spotify:track:1VoJttdilLYpbpYN142Zek': 0,
#  'spotify:track:1RM7XdyfDnksC1ukt4y67n': 0,
#  'spotify:track:28YLWwEB6xnJQYN7e062rH': 0,
#  'spotify:track:5SqSckut3FcoQKmGkMWgp1': 0,
#  'spotify:track:7t5m6zRwIEBxmPt8lNoPPi': 0,
#  'spotify:track:66UVpCZ5aH3VV3Ic3PBUrP': 0,
#  'spotify:track:5UPwc30oJ4KhQYctNfv34x': 0,
#  'spotify:track:5hmO72DpMfddRFBbVdPoEX': 0,
#  'spotify:track:0Gi17qCJh9e9RJxLaYkm9l': 0,
#  'spotify:track:2PUQu6RlN3DDJOoJ26JW8u': 0,
#  'spotify:track:5JvTl9PGOapS3D7BIGjlSk': 0,
#  'spotify:track:0UpkLDlXZhHQ0OSA2rRDfC': 0,
#  'spotify:track:2BwFLgV3bXzuSJgrchJIRa': 0,
#  'spotify:track:1aq4tEEWVhED5nOCaQbh0J': 0,
#  'spotify:track:4oQb8W4UyZNDcMopArPads': 0,
#  'spotify:track:57tHLcq5p05U5swbgi8Enz': 0,
#  'spotify:track:2YtF48bjcdbZ6x2dHtIJyT': 0,
#  'spotify:track:0qThkShRfPfRxHPN23vFMm': 0,
#  'spotify:track:7HIpCuFjnPs44toXXIGVQr': 0,
#  'spotify:track:6hgrEIw79zAqbanpOUvVu9': 0,
#  'spotify:track:39FUQfWr83jRNr75gJvrzo': 0,
#  'spotify:track:5MaWgjCX6sXKEV0FaJEqeA': 0,
#  'spotify:track:0L1YMWEl9M2YLdjNlvGtES': 0,
#  'spotify:track:4to7VJU3lLWdN0kKDu4c7N': 0,
#  'spotify:track:11Bae0OQRhmgbzOHHv9vCY': 0,
#  'spotify:track:1eSYyimaOs2d2arhk4sOzI': 0,
#  'spotify:track:39f0VCdtsaH21xJEcg4cef': 0,
#  'spotify:track:481TjtMqd59htn8HMV7Tt5': 0,
#  'spotify:track:5TGKsJomlJR6uphMRbgv43': 0,
#  'spotify:track:1Ls7KmMnLCz6tfPZ665Maf': 0,
#  'spotify:track:6OiKLQ2SuDpzmuHpBuoCOa': 0,
#  'spotify:track:7L0fLjJOALM89ldfZHQzIy': 0,
#  'spotify:track:7h7abTO0iX02zmucEJD2w5': 0,
#  'spotify:track:7mXLYAU55bGF40dMRGRtUd': 0,
#  'spotify:track:6PfY4eSA4xy22lsPB8KhQj': 0,
#  'spotify:track:2GE8tk05MSA4GQUZrmHPdP': 0,
#  'spotify:track:23jXWZxfmhEWSb2Fc28KH4': 0,
#  'spotify:track:2rlALrxM7bVTjNGe7tYJIL': 0,
#  'spotify:track:3JL5cjX3pwjmlvsxXW5zXP': 0,
#  'spotify:track:5RqQm6NGR3X042Lhs81vTs': 0,
#  'spotify:track:6xAieFpZjRKp8EcDYqu0SY': 0,
#  'spotify:track:3FydQFu1BxCSHOyWQnjkM6': 0,
#  'spotify:track:3BGOIcM485IijlFatNNBUp': 0,
#  'spotify:track:2NWaTtHcSGXMsDx8XiGhVy': 0,
#  'spotify:track:0PYBedpBvH6mP0H5N03JI8': 0,
#  'spotify:track:6ayEZ2UQgphs4ugLoawE15': 0,
#  'spotify:track:3AZ4gcSWBaHdQz5RRmmpq3': 0,
#  'spotify:track:6pqpAcoLOA9acmAYMg2vXr': 0,
#  'spotify:track:1s4EebkreNL2nXJ2NOtzg6': 0,
#  'spotify:track:4TrOkJD2odEr1COlfFzpzG': 0,
#  'spotify:track:4wMvpyue9mc8Xb9K6vxFtu': 0,
#  'spotify:track:25QnpKUEwcfD7B44BVmk2X': 0,
#  'spotify:track:6HL82YFhrIjpjGJknJzFgg': 0,
#  'spotify:track:4SOvERWaBC1gbo3LcbTVW0': 0,
#  'spotify:track:3xZ4DTCJJF1opPwJKzKDmb': 0,
#  'spotify:track:5Mai8CdYF8IiO7LWJy1hEA': 0,
#  'spotify:track:4jrhvcTU0QsVFUgABoURU3': 0,
#  'spotify:track:7ikCmQY1vPXO4Dt1WQzOlV': 0,
#  'spotify:track:1CidH7ayBvdBH3kmG8nUpw': 0,
#  'spotify:track:556F9hlMBhfe7L78SkwkNu': 0,
#  'spotify:track:10gn2LjuwCDnmO0m6UZsWZ': 0,
#  'spotify:track:5370n05yaN4Zdoev4BhtWd': 0,
#  'spotify:track:4O4qpf5vsz4IRP7RciFRKI': 0,
#  'spotify:track:3jVGcvU7pOlnMZUQS2kAPF': 0,
#  'spotify:track:6gQhZY0MjG5glweGqXe2oL': 0,
#  'spotify:track:5nogYFaVUdhGyOZJbdJ7Za': 0,
#  'spotify:track:57NsxnU26KboqKGFkHW7O9': 0,
#  'spotify:track:13B96mNX4WHBJddY97Prlm': 0,
#  'spotify:track:2W6gS1z393Exu6HOQhxWbx': 0,
#  'spotify:track:1fzCOgltYO3vIVfCMieqTI': 0,
#  'spotify:track:3OjAmSVGTZ8BBsEsMTLri9': 0,
#  'spotify:track:0ZagjpZ0fErTiVSlt5j9j3': 0,
#  'spotify:track:3YOCBeYGt96MC1aopLJuyM': 0,
#  'spotify:track:1dwimrRmYToh4ojzEfwid5': 0,
#  'spotify:track:4qGK7cmzPfg33DBy6O0yJ1': 0,
#  'spotify:track:1Ud7FWi7UXYXzDsOnkQYMU': 0,
#  'spotify:track:7BVwi9cIzSc6tpyxsp47vJ': 0,
#  'spotify:track:7DmiHaP1MxL9i1p0kHhXq2': 0,
#  'spotify:track:6ls6Wxw0iivqDIQmlFeG6F': 0,
#  'spotify:track:0xLoYaRyQxTDR7kNIo69B3': 0,
#  'spotify:track:7cxg6WIDYoXza9QAOPDRpT': 0,
#  'spotify:track:6Fha6tXHkL3r9m9nNqQG8p': 0,
#  'spotify:track:43YnOHuci8PolOAzI7XoXe': 0,
#  'spotify:track:2qEv3RLo2KTgjP844901gV': 0,
#  'spotify:track:0flEnO91yDqBreMjCayzBF': 0,
#  'spotify:track:32fDz5sQmtuqukL5sYi4Yk': 0,
#  'spotify:track:19478RhU7tV6UkD8sWcxo7': 0,
#  'spotify:track:3Y4GIDfKuqx0RTEgI1a8oE': 0,
#  'spotify:track:1P8fLJqOfUu2WyOmSsgEir': 0,
#  'spotify:track:58DuAmlqBhzLonfQ86cJ2m': 0,
#  'spotify:track:5JkvBj476SnYHJVrhzhFfC': 0,
#  'spotify:track:2HHCdnacK4EycirFzMdJmc': 0,
#  'spotify:track:7InAqAogwF3YWfWEBBoUyy': 0,
#  'spotify:track:30LzirhhiqH5K9AlUKr2fV': 0,
#  'spotify:track:0x4zwgjwBtCtowyQO3iQH8': 0,
#  'spotify:track:7FrmBo8y6vtTvPSzA0Rfsd': 0,
#  'spotify:track:0xE9sF8mXf6I4bsJ3PCxrZ': 0,
#  'spotify:track:2urNgWEjMZJI0Ch3TLyDfX': 0,
#  'spotify:track:0rqhKRdHQkbcRmKbhiAcg2': 0,
#  'spotify:track:0bUavqp059H8ORhNZRCdLh': 0,
#  'spotify:track:5FkXFwDMVNGPdCVmGyE9hQ': 0,
#  'spotify:track:0MhJxJSG6NtYAnBKbGzueC': 0,
#  'spotify:track:2QbKvwIRh85Divgk4mNcq6': 0,
#  'spotify:track:5rr9uYCgwuh3nI9seshzAu': 0,
#  'spotify:track:6NJgrFdaAVaAP2fN8ge1tu': 0,
#  'spotify:track:5lEO4bmwpmAVg4lNpKXO5o': 0,
#  'spotify:track:1DlIyeeCOkRYHNhy3QjAuh': 0,
#  'spotify:track:4tF4oZATvNWwqWTGa3RYvn': 0,
#  'spotify:track:7bFE55bwfWHM5IlWDSnTRH': 0,
#  'spotify:track:5e9DjtTeY0oi0Hr8MfWxw8': 0,
#  'spotify:track:2RMCFWjVd66V6UzXRcUtS0': 0,
#  'spotify:track:48WNXZNGIdaBjDz1RPPegn': 0,
#  'spotify:track:5fNgVC78pE7LKT65Kfkyvl': 0,
#  'spotify:track:16L9zLbZrFl0iNveGQiK1T': 0,
#  'spotify:track:6zrJLhslleCHby0wbUnvVy': 0,
#  'spotify:track:2nMOodYNHBAQ3Kc1QNimZU': 0,
#  'spotify:track:3AzjcOeAmA57TIOr9zF1ZW': 0,
#  'spotify:track:6uAFJ75WDAoAPyCWJAtvks': 0,
#  'spotify:track:0vQcyuMEfRBd21ojZ62N2L': 0,
#  'spotify:track:7sfeMasFUdoHXstGoprj9v': 0,
#  'spotify:track:6YPpOUPDkrcGOBMXZju96h': 0,
#  'spotify:track:5lWy56wzG69YCts5BV9fth': 0,
#  'spotify:track:36vyr7BqkrV3KTNwPyib3d': 0,
#  'spotify:track:1Cq0GKFTzFabtj7DQ2kUkP': 0,
#  'spotify:track:1fxXfL9jSNbiPmtyvBDYzX': 0,
#  'spotify:track:2itjDgLVxad5cAY4LB52KL': 0,
#  'spotify:track:1usr8G645qLjRvwZGappbL': 0,
#  'spotify:track:62Yq2kaP5hQekzdAYlRRE8': 0,
#  'spotify:track:0cThinjTLivrKTuACU63VF': 0,
#  'spotify:track:75XZ1alf4cAVeFFw5cHynT': 0,
#  'spotify:track:0LAEdtStkfUcvvsItkW6GA': 0,
#  'spotify:track:3ztENBSxGN1eo4IJ3Roxki': 0,
#  'spotify:track:5hJUI2Q5DaDu56cpW9BBBa': 0,
#  'spotify:track:4D7lKXsiE7OLzLWuPcP5Sd': 0,
#  'spotify:track:7qRmdDl9dnHkFT4MMboG7Y': 0,
#  'spotify:track:0LiSSTgysOjNcmpSUImimS': 0,
#  'spotify:track:5fpj84RsT9cOTfWUCxBTXu': 0,
#  'spotify:track:6jXkTqOYgs27YVPkq12UpE': 0,
#  'spotify:track:0vjYxBDAcflD0358arIVZG': 0,
#  'spotify:track:1odEpn9xw2Hom1tRxS1IHR': 0,
#  'spotify:track:2WbOvUGQtr8lmkiRIOQO2X': 0,
#  'spotify:track:558vVMSzi2dwyA1O5l98Lp': 0,
#  'spotify:track:7Gkse5oUgdsjBeVQn980ce': 0,
#  'spotify:track:0taezNznEhMFWkyjSS0Tfc': 0,
#  'spotify:track:29Dmhs2XFwBfl2odegxGF0': 0,
#  'spotify:track:312WNtMs3F28cUukaPY9bo': 0,
#  'spotify:track:52Qu0no0NBho3zyRmjlsHn': 0,
#  'spotify:track:248OFOZef6ShXv6DGgbnxU': 0,
#  'spotify:track:39KG4kom3enSx4GTThuDGt': 0,
#  'spotify:track:5bgwqaRSS3M8WHWruHgSL5': 0,
#  'spotify:track:6AIccJIWHGK26xi34FAkwl': 0,
#  'spotify:track:3JTtZUOiZljuWbNiasfHB6': 0,
#  'spotify:track:34izzOmykADkGT27pUjUvJ': 0,
#  'spotify:track:4V3VshJLUTCIWa77YiAkvM': 0,
#  'spotify:track:25YvGDl2zSE0pH8jrMZ6aY': 0,
#  'spotify:track:6SWHTMywuTXLFlMQ75cAuu': 0,
#  'spotify:track:1Ob94QesoxHSBrypyBbdfd': 0,
#  'spotify:track:67kXYrMTQbS7MVbXyGyxHm': 0,
#  'spotify:track:6TVs7Lap6ZcrpZk1xfOgtv': 0,
#  'spotify:track:4cawaZVzboa3UYqgR4kalj': 0,
#  'spotify:track:5rP9Weh1uFtlyRGqnzyQnd': 0,
#  'spotify:track:0oirMI8pqPHJiJFTX1LhKh': 0,
#  'spotify:track:5kiZpF6a7kxZLurZVSewtw': 0,
#  'spotify:track:3g9mw4A8vdljOKgwrit88g': 0,
#  'spotify:track:4lGb7vjGqK8OZhXRozj0Go': 0,
#  'spotify:track:159ld20LzWoNcdk5HmPjjW': 0,
#  'spotify:track:6UI6aabe8NSRgTVySHn6CP': 0,
#  'spotify:track:4YxPUY0MvL7ONZcqhvM57G': 0,
#  'spotify:track:1PZRtfP1HBm0SmbUJFzM2Z': 0,
#  'spotify:track:6UxXgCceDiEtIIeW7aXz6o': 0,
#  'spotify:track:1Mp01eCl1HRNZyT0uo7x3l': 0,
#  'spotify:track:3Vyt2a2bLsh0BpBQLMzF97': 0,
#  'spotify:track:0lKq53PvShNMZfEG89dAfI': 0,
#  'spotify:track:63TeeYWtLUA6YRLhLwLzY8': 0,
#  'spotify:track:1CxSLPOLHpZ7pFAWjZBxz5': 0,
#  'spotify:track:7LeYLq5lZgIZ41SU9wPePl': 0,
#  'spotify:track:5yp6OUTfQ5OTPC7LWZD4PK': 0,
#  'spotify:track:4yYbYckiuG2Pe7pCq4IBo7': 0,
#  'spotify:track:66hwbAihmAccG6hAxEjEFi': 0,
#  'spotify:track:38MtLhFTRqtB6PxzDVYsKP': 0,
#  'spotify:track:1GDldqAOtMm8TMWm0btmLI': 0,
#  'spotify:track:2KZovFEIfWfz6atAr9RVwD': 0,
#  'spotify:track:6kWh4tmlKHmvx5CWxTa7Ay': 0,
#  'spotify:track:4BFhnSmgmwkbJ8QWx2CJwC': 0,
#  'spotify:track:4nHlOHDt8o328IuZWF0oQQ': 0,
#  'spotify:track:6rQi85JWh2LcMLwc4SFZOp': 0,
#  'spotify:track:1BDT3FQWInnWoHPAy40801': 0,
#  'spotify:track:0TZXG5leRqwiyQC9dSq0Mm': 0,
#  'spotify:track:77K84rOcuArs2LFsaOOJXd': 0,
#  'spotify:track:3p7BCFNV2p1aiZzUydrYYT': 0,
#  'spotify:track:7mlyFZ5i2wV0auOn15jSl9': 0,
#  'spotify:track:0ahyHM3OLhd5LZnT7MyCvw': 0,
#  'spotify:track:76a55LrEktkP39bDBNKx7e': 0,
#  'spotify:track:3j8xzKjBHx5ZjTz59UF8tl': 0,
#  'spotify:track:5wW808Ff6rXDjmSdOngd4A': 0,
#  'spotify:track:2dgwNI068TB25mLuUGvNy8': 0,
#  'spotify:track:00Ok1K4iVXGhMTguVqtLec': 0,
#  'spotify:track:3MnBlnCbjYubZfhggHcPzz': 0,
#  'spotify:track:5ZbkmehK4biNOMGZxKxtbJ': 0,
#  'spotify:track:0n6OsM7bGbigdsVl6pWRFG': 0,
#  'spotify:track:5xnriYz58DnBeLPqYADDJ1': 0,
#  'spotify:track:1nibh74Ojzm5hJvf88vMhI': 0,
#  'spotify:track:3NbyKGeZBRVhCezW0qeTh6': 0,
#  'spotify:track:5lWNzRLwFevngo09cD6F22': 0,
#  'spotify:track:0iG02pKaTFTF0UtcpkXxF1': 0,
#  'spotify:track:4JIzr4cDDfQNDctWx1V54y': 0,
#  'spotify:track:5icna5cfuXiT26NXNlzgNX': 0,
#  'spotify:track:6ykCgFYHGrxazIiW9kmtqd': 0,
#  'spotify:track:0fqZWuVOcv90tvAGs4bYIz': 0,
#  'spotify:track:4eOsLL4eWlvbKqwv0esb6r': 0,
#  'spotify:track:2WI6gfiOCXySvD70xAsUKj': 0,
#  'spotify:track:2VdT56BGpdqNHUgOe1j5vc': 0,
#  'spotify:track:5lZZmityu9TAjNvSY6GLhR': 0,
#  'spotify:track:5ffntNJnJOeFv7b7DCd0Bw': 0,
#  'spotify:track:09IOPhEh1OMe0HD9b36FJk': 0,
#  'spotify:track:6IaieqiCVvsNvEt6Y7yOFa': 0,
#  'spotify:track:4qWCFTuNnmGNdY4egtb4ZY': 0,
#  'spotify:track:1ZemPoaj7LBj1RAQrb89EC': 0,
#  'spotify:track:688QpQAwqsLdBR6lr13wK1': 0,
#  'spotify:track:0R6Jlsq25eZB3Wftpxi3oF': 0,
#  'spotify:track:1D2L6MefbXon28PzIk9I3r': 0,
#  'spotify:track:32lItqlMi4LBhb4k0BaSaC': 0,
#  'spotify:track:0MrRAUcB8AZiB9ue2VOBYe': 0,
#  'spotify:track:2kP1ujXHn0mNqFbiT3zob8': 0,
#  'spotify:track:6WRjufZUoxjaUNKOJ6QhWp': 0,
#  'spotify:track:015QxjqYIZ7eKTJYjDPC5n': 0,
#  'spotify:track:55zTc30BLHsy3HJOspZ96K': 0,
#  'spotify:track:2Cz212i2P8Uk4ZuorH7KO8': 0,
#  'spotify:track:5WhNe8bgleipQgKeunAxj6': 0,
#  'spotify:track:2XGEpFt3322G8IHsldVqZh': 0,
#  'spotify:track:0lnYrMmUtjJSEwVKj8PxUS': 0,
#  'spotify:track:7zTsQEfFbvi8eMXOK5z5OY': 0,
#  'spotify:track:3AiXzUyFAFZVBGVAADPN5a': 0,
#  'spotify:track:0vza2CsUtpjydQVV2E4TOm': 0,
#  'spotify:track:1uy3zpVkTSMzYpcMhAz30s': 0,
#  'spotify:track:6EyseMtWbRgpAwinivVB3D': 0,
#  'spotify:track:2yV51Sjk2LGcCKsE1ssbhQ': 0,
#  'spotify:track:08IJfZJUd4yg5xlLEjOPcw': 0,
#  'spotify:track:2syyQhy7eVekifoG1lw5JX': 0,
#  'spotify:track:4hwdgAy1z38vrFu6Eiou7k': 0,
#  'spotify:track:0iRjVAJFAqRRfZBxbFkY6H': 0,
#  'spotify:track:0isNcoafH7FNeL9aECWthp': 0,
#  'spotify:track:4JzVwoBuqObQ0XFV4kjrcT': 0,
#  'spotify:track:37COAMuaoo51Blvin941Tk': 0,
#  'spotify:track:1lERZub1j4jIGwBOmtSjbN': 0,
#  'spotify:track:59F7GAoBNHeG8mGvclEXj2': 0,
#  'spotify:track:0HPQoGM7LkIFYZjs83qenN': 0,
#  'spotify:track:0bbwDC97GEft4c9cqxiPes': 0,
#  'spotify:track:14Woq9fysZOr38UaXWQzLq': 0,
#  'spotify:track:37BhC44RtZnNIa1QUbPPR8': 0,
#  'spotify:track:5fMT4ex2pxIjYIaJ5xutln': 0,
#  'spotify:track:4lPAQZMshAYDpUytDE6Uss': 0,
#  'spotify:track:4YHU1EqRLWwy0ESKPzp10Z': 0,
#  'spotify:track:7ktDrU5ItPwpb2CUwUljF1': 0,
#  'spotify:track:0zhM7duYdq9vHRTJW2wg3c': 0,
#  'spotify:track:2K0jiO4GuRp1kdBbAEytqU': 0,
#  'spotify:track:7iBc8xrRQoNKjYTsyLs55y': 0,
#  'spotify:track:6AIXBazryGtbmDsDkh93Oe': 0,
#  'spotify:track:17iJelHV2vNOaekV4mON17': 0,
#  'spotify:track:6qAlFn7JQPbcnhYbRYYEno': 0,
#  'spotify:track:3Sz51kDvFhngNDinn8WRb5': 0,
#  'spotify:track:0C4BoSnkXGGAbpZ1hHcbBC': 0,
#  'spotify:track:6mpVZuFYZ0DuIHXvSwR27g': 0,
#  'spotify:track:6D5sRscjhPXgpphwIdrDEP': 0,
#  'spotify:track:23TlmRDKp6HJZwlokR9sXP': 0,
#  'spotify:track:6bgwU45L5Xr5AnbijnI8sg': 0,
#  'spotify:track:3eCgRFEEjUR5JuKruXN3Qo': 0,
#  'spotify:track:2z9mxvZi3glTnztcvQviqm': 0,
#  'spotify:track:2YZ9CwBoHQ78zyLcJwYS2C': 0,
#  'spotify:track:2qXTWfiT1LAjNPvIWX5Zy0': 0,
#  'spotify:track:5nExXJDodsdvXUWKSJ9Lp2': 0,
#  'spotify:track:0nRgj4hnqJpyWCQgGm67D3': 0,
#  'spotify:track:2g91sGGbwQLpsOj6gIsqH9': 0,
#  'spotify:track:5oHcOMlML08CpvdptBKo1e': 0,
#  'spotify:track:7dKIZJzZqMMaJH0dsfR9Pl': 0,
#  'spotify:track:2Ai1AXqVUIZ4F6VwA6GU7t': 0,
#  'spotify:track:5ecQ9HozVAh5UCBFKkTj1o': 0,
#  'spotify:track:4wOX94CO9fL6tTy1MTonYF': 0,
#  'spotify:track:2hgurxfHoYqG724iDfCGvd': 0,
#  'spotify:track:0jCLTFPFhtit99vhJo9tU9': 0,
#  'spotify:track:4aUdcdlOPuvc9BbqpsnQ7b': 0,
#  'spotify:track:0qzbwqnFo7CfuAY25UkCWw': 0,
#  'spotify:track:038wmePvWXBhKxEklDjwEB': 0,
#  'spotify:track:6CnlvbnuMH6R4zpVDEctnn': 0,
#  'spotify:track:74Qt7VRpNM7XuDVTkTYaJI': 0,
#  'spotify:track:6vN3WGRFoP7CzhbRrPOkIh': 0,
#  'spotify:track:3b41uzbEK5QDlqsoOCufag': 0,
#  'spotify:track:6iS3GzcVUhG8QYuP3Z9oxS': 0,
#  'spotify:track:1bUz9AuPuSpHJ2a6M2iOYH': 0,
#  'spotify:track:2aepkqfETHh3XCVFxNkn2P': 0,
#  'spotify:track:6ds6oS8HVsmtKNLcbmOTXY': 0,
#  'spotify:track:1nrg3kORD7kHjJAto3yfix': 0,
#  'spotify:track:1V4LPqBNYv8vn3JYaHSpbk': 0,
#  'spotify:track:2ACLzaKgFc8HUt8BmE6Xns': 0,
#  'spotify:track:6tgtntNcNzweVLQHvGi8md': 0,
#  'spotify:track:1p3sxF9W6s0IxRpAL4ojBZ': 0,
#  'spotify:track:1MYQvaAUKBLEp8HChXdD6s': 0,
#  'spotify:track:7w5rh9x3sjgTRirjfCKsjd': 0,
#  'spotify:track:7aZ7WWaajRXSHPP3lbzoYO': 0,
#  'spotify:track:69pOaF9WArEoUCt90NiDdT': 0,
#  'spotify:track:6TMEL7vpevM8hwGi8okKqp': 0,
#  'spotify:track:6q6QN3nlvK2OTaHITi4dq2': 0,
#  'spotify:track:7f7MFSEIgJ4vQWsD2oe10W': 0,
#  'spotify:track:4nEEHU4SemzGQnvN7ItLxT': 0,
#  'spotify:track:7pAxc6GEhnESVjl1AHBzIU': 0,
#  'spotify:track:4ZVgmpUb2ywdkJTQxNtd9O': 0,
#  'spotify:track:41ScGrf1AVWjEw2IrpocBw': 0,
#  'spotify:track:08gvuNNTrxZX1A37VP3HT6': 0,
#  'spotify:track:3D8uDTWR1UhatnBpa6fW1C': 0,
#  'spotify:track:14YGWneWiRfEXXYMo4qVOD': 0,
#  'spotify:track:0S1hcj5VDey5sc4kMgULda': 0,
#  'spotify:track:1aPa2oT4uoSpp2KuNfN8fw': 0,
#  'spotify:track:51l1ZjYZkaJhH77YX73oyn': 0,
#  'spotify:track:4e8XaggD6PJ04GMcx0Lfkb': 0,
#  'spotify:track:20IUhlKKzDpSjqb51C4XD7': 0,
#  'spotify:track:0A0YfLHyaUaXzvYcYPDbSB': 0,
#  'spotify:track:0V11rUAQvYjJ2jJRc0e0BK': 0,
#  'spotify:track:5Ed6zPsf01JZxGhOtA46tk': 0,
#  'spotify:track:6pAnoQB6tGh1tBLvItwKqu': 0,
#  'spotify:track:3gNynXzWWUBDm9u4FLywaC': 0,
#  'spotify:track:60MJeKBy5jXLkcN4CoRIOG': 0,
#  'spotify:track:1RmpCq7WxpJtzlVTyjPEcb': 0,
#  'spotify:track:5wUvkw5LVMWdhnvpTTtynL': 0,
#  'spotify:track:1oePPnAkVtu8JQbR350NhK': 0,
#  'spotify:track:0IcJIAnm07BqZg8h71Crd0': 0,
#  'spotify:track:1RxAzmAuN6KldKrMeVKkf2': 0,
#  'spotify:track:3rcHDFyLTeHNMKlhxQmy0o': 0,
#  'spotify:track:5RR5N6JncNjUQCOlNPXXU8': 0,
#  'spotify:track:1baWTzEA3bHpK2nMmomDmj': 0,
#  'spotify:track:2wZ99JXUqr6uoEcWbEZVbf': 0,
#  'spotify:track:0gTnRw8eAI1Tu3vj1fKLDw': 0,
#  'spotify:track:05k6iNfoyoanMoYHQDLSnM': 0,
#  'spotify:track:2Ej4Y4Y0Pm7PhgHtUtUC2u': 0,
#  'spotify:track:2zwTt96w7W5EAsIDAEXYYI': 0,
#  'spotify:track:0LWafVIV4xvippou3djh8f': 0,
#  'spotify:track:0bVRwFP3U5ENByD7ZXqUBM': 0,
#  'spotify:track:5HI8GEEfrBd2IypYCXDiCZ': 0,
#  'spotify:track:5Qv6BdRJ7wyvNvoQm3C91s': 0,
#  'spotify:track:3zzgyi4qAwx6zZBbTObIC8': 0,
#  'spotify:track:4yOfEDhOGTvJMNqneG6jGO': 0,
#  'spotify:track:5oGM0hp8eepDQ1zz2ybYaG': 0,
#  'spotify:track:1DEWThcexgXsww33buRwjj': 0,
#  'spotify:track:1Yb9pIPxX52UekANEC7d9n': 0,
#  'spotify:track:1gUtoBrA54syh9qR70CaNK': 0,
#  'spotify:track:7bj42lKiCe2Xmmx4ewpORe': 0,
#  'spotify:track:7yzD5mP5WcFq9U9EswFyBw': 0,
#  'spotify:track:6e2VUiBEpkfxPkNVrNxJIR': 0,
#  'spotify:track:5uTQMYC3iw13RBN0a1bNSL': 0,
#  'spotify:track:7H5z5uEyt29WklcDNL4Sr5': 0,
#  'spotify:track:3EsW4otT3842xdOosEAxHb': 0,
#  'spotify:track:7EZ3gDixP52LTIZeJPlULI': 0,
#  'spotify:track:4zJMLsu4L2RqwW5rOlVxHb': 0,
#  'spotify:track:4wKcdpm3vqZ960UlufQj3k': 0,
#  'spotify:track:0AmHen3jIJEUburl5bLkPR': 0,
#  'spotify:track:0lwnbBaycf45TnpyzfTdyq': 0,
#  'spotify:track:3bpYW0A1HU0kjXyptlFQC0': 0,
#  'spotify:track:28ePWFvFNHrkAJh6Sl01dg': 0,
#  'spotify:track:4P3FJMT2ZaF9nE36RJg514': 0,
#  'spotify:track:5iLW1l1IdPV1omFPR3C8zG': 0,
#  'spotify:track:1iC94VGBlci8FOyGyDwWIu': 0,
#  'spotify:track:4mfLt3g1xUCQx44jzImphW': 0,
#  'spotify:track:7HbQ3rqfob7h5tP4nyYtOw': 0,
#  'spotify:track:4CfxlFpty3kFzquuDnuKKM': 0,
#  'spotify:track:1z0eRxPiUz1AkpdX7xRBp8': 0,
#  'spotify:track:6wYH3FeGHwNr2E9H1ADll5': 0,
#  'spotify:track:7oZ7F7TdPdFqywz6ttYZzm': 0,
#  'spotify:track:64sd7wZyH8X2JmjzJfD1v8': 0,
#  'spotify:track:1mXodH7QcmZuU2D9IuAlkx': 0,
#  'spotify:track:5w3HYJEAOcQpIr4ZqkPy81': 0,
#  'spotify:track:0nwHbQ09NlNpYggI4T0sZb': 0,
#  'spotify:track:1pCXHVpLYsI43foeqhi88x': 0,
#  'spotify:track:2Joj5KWiLxlHu35dvBpol2': 0,
#  'spotify:track:7qkkd1COeUTxyUjtqTYVQr': 0,
#  'spotify:track:5LpSOWK15E95kkeSiEKEZ8': 0,
#  'spotify:track:72UEEXrAMmhUchvbs1qHWa': 0,
#  'spotify:track:47CKs7eGj9rtEjHq7Hcpbs': 0,
#  'spotify:track:2xowT3VWuuf4ThSRbQDL5J': 0,
#  'spotify:track:2O55fdEmHWLJe2w2eGKwX4': 0,
#  'spotify:track:4Q1L8qlrGqKOy8pAnP8bWR': 0,
#  'spotify:track:1P85f6JuFXI0gsIlDlGnBn': 0,
#  'spotify:track:09hgfjFdBsWb6cGMdloQMp': 0,
#  'spotify:track:4BcWcZoludxrNoPUw5napp': 0,
#  'spotify:track:7nvlKdzkw3EJ8DsaN8YjZ1': 0,
#  'spotify:track:3iDY4SzUHPkC3WTXpfxXJG': 0,
#  'spotify:track:31DEFJYOtrBjIKdTF5Ea9g': 0,
#  'spotify:track:5TlnpHVyQbUpSnpl34jcwy': 0,
#  'spotify:track:2pzyyL79A1VT0EQWEJ4TQu': 0,
#  'spotify:track:0fBAAxkdQryPR4zJDxH5y5': 0,
#  'spotify:track:2WWruw7ul9N7eqoHELyMc2': 0,
#  'spotify:track:6wOCaV1MY8CN2ujNJSfr5z': 0,
#  'spotify:track:6sDCgB1Ulh7aw92mk0opyd': 0,
#  'spotify:track:0HXhk04CE4fE2Xr387TET3': 0,
#  'spotify:track:7fOPVfABNLg3sxtgXBhBdp': 0,
#  'spotify:track:1QUuqPaTbBjFOvYjzq5Lso': 0,
#  'spotify:track:18bhLb1XbBQbRj9QAvIiHt': 0,
#  'spotify:track:1lOvSqQIVIkNaDZlt645d0': 0,
#  'spotify:track:5oZvmo8ARpuBbaGArm8cBn': 0,
#  'spotify:track:3rtuukjxyg57bDRZbkkt5l': 0,
#  'spotify:track:6kbs6lHYzEyjhi7Dss2yVL': 0,
#  'spotify:track:2DfBHbZ1rq4Nu1pzKNAwxY': 0,
#  'spotify:track:44YAJYlDg4EECrecze8BU2': 0,
#  'spotify:track:3DgoM4s0T7VoHEQkp3xUsW': 0,
#  'spotify:track:7EqbX6KDCvWms0m8Rbmt2q': 0,
#  'spotify:track:7aW0z1jKq6FgB7ffpbocg6': 0,
#  'spotify:track:0EZL3sv66teJRAE4t1NLsQ': 0,
#  'spotify:track:1Bw7kDeY4ZPfUo5UY18tOO': 0,
#  'spotify:track:03Yv8adIIOsRACDHLUYS9l': 0,
#  'spotify:track:4Ka1hOiCQw1a5RVyzW4Xu1': 0,
#  'spotify:track:4lU7OMm9xWPNjusCWVJcPY': 0,
#  'spotify:track:0jKqcTDzbUv7chWlJiAuR5': 0,
#  'spotify:track:4fPVJz7EYTqCqgXxLjQrSn': 0,
#  'spotify:track:491FFHeud9a0KXZ66QunVn': 0,
#  'spotify:track:5lOV1OnHMswQkdYsiWlQTo': 0,
#  'spotify:track:4kPF8KNfCkQQkL22YoOJir': 0,
#  'spotify:track:4tYgcGZACShICXeJh1CSAz': 0,
#  'spotify:track:2O63bJ9cv7p3dziHbofVqa': 0,
#  'spotify:track:49JldZeTfED1yZiMBIRkSG': 0,
#  'spotify:track:027xs7hdMeFUiYaXiwtgfm': 0,
#  'spotify:track:5TDxhVHsd9AxcWieCsYtcs': 0,
#  'spotify:track:7M25LxL4H1F8kWtSwM78Iu': 0,
#  'spotify:track:1Yd40OrjA8D1F8IgMv5BFI': 0,
#  'spotify:track:5O8Tg0laVqXLT9tvcdQyL2': 0,
#  'spotify:track:2Pet492PHE6ntVncylsQ1k': 0,
#  'spotify:track:3Vajk3JwfJDCTLNslkrmce': 0,
#  'spotify:track:3FAzlNPlVImGsbjnHHft6K': 0,
#  'spotify:track:1Se0r96r0gnqg67kJPmESc': 0,
#  'spotify:track:64BbK9SFKH2jk86U3dGj2P': 0,
#  'spotify:track:0GcWf1Cc4ixN35D3O9VdcP': 0,
#  'spotify:track:3QJnjJH53Ocg22MaLutrgJ': 0,
#  'spotify:track:6WUjz18yIeTGDR1E69WHtf': 0,
#  'spotify:track:2xDHUsWEsH33sKbFqDZPFj': 0,
#  'spotify:track:2bo1tTjK87OHKKUDFthqHx': 0,
#  'spotify:track:49colNVoLFcMszng9O8w4h': 0,
#  'spotify:track:0O8RjwNco465s5o9Ix9IYj': 0,
#  'spotify:track:0tGkxA0oybkQ3iR6LLXPjZ': 0,
#  'spotify:track:66wnTJJ7Vo0GW02CMP3etR': 0,
#  'spotify:track:1XxCiPw07rd1ytYnE7SoJI': 0,
#  'spotify:track:3BW34zpQNgRUwuQ4eUyzMN': 0,
#  'spotify:track:0809RpHic1xrZzh9CT4wXo': 0,
#  'spotify:track:28w7CPWQCqQxt0YCzDN75b': 0,
#  'spotify:track:3w4hulywDgU9V8D9qw5B08': 0,
#  'spotify:track:2xbfhyjjSQMzBooLs7ZmT8': 0,
#  'spotify:track:4QRs1M6DYXbNkHHWlhvYvk': 0,
#  'spotify:track:59132v9YstEM8IGCDAJhrf': 0,
#  'spotify:track:37vKXyqfAdyi56M850LcbE': 0,
#  'spotify:track:5dc9sIEET1NT1iW3S9rMpZ': 0,
#  'spotify:track:6JSI6Az1ireeewiTSCjwXd': 0,
#  'spotify:track:2GZzK3pJ8JoJqPFp5V3wvy': 0,
#  'spotify:track:7CHi7twCF9P6wTm0KtpKBA': 0,
#  'spotify:track:77dex4hQaGdIt8aioHWhDL': 0,
#  'spotify:track:42hbE9hxMxRDizdr9UkzTj': 0,
#  'spotify:track:1SjMeC7cK1SiK76J0qm5mi': 0,
#  'spotify:track:7JoW6Fe7lnAvuXY99OmBlC': 0,
#  'spotify:track:3zdZYMK6gpCBXoSBNqEwCi': 0,
#  'spotify:track:25p4XsP6BRF96U3CaSq7qf': 0,
#  'spotify:track:2STKkcZkAEBGU3ekVrHYDr': 0,
#  'spotify:track:6Ho4l3GybjYrURJiT8wAbq': 0,
#  'spotify:track:0dYL7lcRjKIckzlaZgbKJy': 0,
#  'spotify:track:33wg6qhynk1XKD6HM1Yaad': 0,
#  'spotify:track:5SI9IqXXoXic1gy93XVdS0': 0,
#  'spotify:track:7N3DKWBC8pKoTf0JzyYKaj': 0,
#  'spotify:track:1wUGFXo5loMTDS5bkFS2HR': 0,
#  'spotify:track:0m8tnq77KFbRDWCKGR404P': 0,
#  'spotify:track:03ZIYIkSXFEe8eKeG6qzE8': 0,
#  'spotify:track:4rYlKl0AI9uUCnFQXSmjFF': 0,
#  'spotify:track:46vItXJiYujbUSDQAGxwuY': 0,
#  'spotify:track:1zB1aOX3EK8J0xjDA7x2TE': 0,
#  'spotify:track:4pvcJGQDEQlCLZVGMtHZ41': 0,
#  'spotify:track:5IFDfQ7UZESBM6OSkvrQpf': 0,
#  'spotify:track:6cYISTrRPCMk8OUkJ6IKNo': 0,
#  'spotify:track:1hPGs5gyh6kLfcjUhdDlwg': 0,
#  'spotify:track:08oKdYVEnfZYMp658masRw': 0,
#  'spotify:track:78qE5ilXApKH7runGc34G0': 0,
#  'spotify:track:2ZM0kZtx64UZ0lK767ZLIg': 0,
#  'spotify:track:7rw1NrijgLFl0ksv6g6bo8': 0,
#  'spotify:track:1pdNj5DPKdH5riRjV5q14o': 0,
#  'spotify:track:38o7uwO297B5zcCfcSbPf7': 0,
#  'spotify:track:40EpyIaP6uIJchvneiSdq6': 0,
#  'spotify:track:2qequd6eNqZv0gSobJ6Itq': 0,
#  'spotify:track:5iENrjtDJvOsIpbPMKJpxj': 0,
#  'spotify:track:6jEQz20f3xk9HfCnQMe92q': 0,
#  'spotify:track:0WjBwFCJ9lFyPrNKAogEew': 0,
#  'spotify:track:1dGbH5Gy0R87dSZcr6j40h': 0,
#  'spotify:track:5LO2wMCcQ01EQMBypfyj1b': 0,
#  'spotify:track:5ouVjFOfqno8RntJuZH50u': 0,
#  'spotify:track:41wA1TuSNxMdQ17loldQAU': 0,
#  'spotify:track:56RT6dtBmiFNUSeYyG0nMR': 0,
#  'spotify:track:0VfZ8soLs3Sjh0aatQJX9N': 0,
#  'spotify:track:5kK0CQYgpRgBrtMNNN47BG': 0,
#  'spotify:track:022b5KP2xqjy8LuS798skH': 0,
#  'spotify:track:5PvWM8RrfJ1vNBoRHviWMB': 0,
#  'spotify:track:0YdP4Kr7HJaWqwuIGvlsF7': 0,
#  'spotify:track:05704F5Uk32MIb9tX5omWQ': 0,
#  'spotify:track:0MeSuyL6pVnhzN4jrkDS0a': 0,
#  'spotify:track:6zezOLouSWKEfMizbzcsad': 0,
#  'spotify:track:3DMLISDQgfwws7KpbCm2LI': 0,
#  'spotify:track:6CocRuwefYkuUs68orrrJd': 0,
#  'spotify:track:0pbr3g8GP1OPCdmHJNtXpQ': 0,
#  'spotify:track:1KRQpyjO3B86ZWSKS9Cgnf': 0,
#  'spotify:track:3J86RRNATHA6dlL9mctyi4': 0,
#  'spotify:track:65AutDIlqEMNVNDt5x2bzW': 0,
#  'spotify:track:1e6ZxoUlQsxZG6GS4MYeZ4': 0,
#  'spotify:track:3pFvXXDuKGsUPsmBc6McV9': 0,
#  'spotify:track:1hdDnQRPinE8hxYhW3uy6u': 0,
#  'spotify:track:6ptaNuDuwRtqK4y1UOarmo': 0,
#  'spotify:track:7jaZSFx0lxKrq9DcDYx7dh': 0,
#  'spotify:track:7nYS7mmZh0K8EbM8DBRwb9': 0,
#  'spotify:track:77TATZE6wbYCtThSQGjA2j': 0,
#  'spotify:track:4nPSn2hRBj84fAjeLjk5D4': 0,
#  'spotify:track:7ddFviC4ObJzizg98keTNt': 0,
#  'spotify:track:2Zt7VPbzQMv1Fs5h7AU2U7': 0,
#  'spotify:track:4ObePnl5sf02pKfYUeGpkp': 0,
#  'spotify:track:1hoaBZ9LLKBs5msZUD8Qrb': 0,
#  'spotify:track:08fllULRfshgwYLOakduiz': 0,
#  'spotify:track:5avRRgbMXNwrQ2hJ6fGsLF': 0,
#  'spotify:track:1xz3sgBCocsNkbrtxbJ5vI': 0,
#  'spotify:track:2Gvu55W0wrCnJYxjQlHYq4': 0,
#  'spotify:track:24gwk2fxBeKaXdsm2P0hDl': 0,
#  'spotify:track:1xvjFQb1MvM5Gsf7B0nqyg': 0,
#  'spotify:track:2s19avn4EIvKsXFY6tnVgD': 0,
#  'spotify:track:6QSWXB6W1FmL0g9dlCrinY': 0,
#  'spotify:track:0HX7ey3NFfhUwwtvimOWtb': 0,
#  'spotify:track:66LH4Vahm6svPp1AZc2HDw': 0,
#  'spotify:track:6qQBYBLq2mbrbvctqNH5O7': 0,
#  'spotify:track:1ycGgux6YE09WtIStV4PD4': 0,
#  'spotify:track:3iTaQmM1pHl7YtzoY5XDUG': 0,
#  'spotify:track:5Y2U8zuAu6GVqNTAxlcTAg': 0,
#  'spotify:track:31O0zmGzyphIpVDG9ilTzz': 0,
#  'spotify:track:27OnRI6jSkxN9EAqZEVHjv': 0,
#  'spotify:track:5ickTiytREZcX3vfYQ2RBJ': 0,
#  'spotify:track:2SNZdHVuZCggYG3jpby9lk': 0,
#  'spotify:track:5xpVvOlrjPMqsXIDeNkSux': 0,
#  'spotify:track:2tm6ZO4t9MoDVvnZyY1hDt': 0,
#  'spotify:track:48zyIw7tMpSeMJnMjQGWjj': 0,
#  'spotify:track:09dqs7fRPkRtbL3C9JwwYN': 0,
#  'spotify:track:5HRfEd9TEE6PaqXogzQiTa': 0,
#  'spotify:track:55Ld212t1YuCoAAwDjLqto': 0,
#  'spotify:track:6lFQSaruBTAHx1wk3N1wxV': 0,
#  'spotify:track:7DYyn5W6oumtdVxFmpmzEi': 0,
#  'spotify:track:7EoI7tzRzwMNLU2Rom2MbC': 0,
#  'spotify:track:1Ks7tVO4tHE1PI3MvRZr9e': 0,
#  'spotify:track:6vLiydkvM56RWrpX4l3Q71': 0,
#  'spotify:track:1cCijJ8USONpvDrbWEew9K': 0,
#  'spotify:track:1eqMNn7L1TN4PACTzhxOM2': 0,
#  'spotify:track:1l4v4zCjoBzjJLNgnB1wu0': 0,
#  'spotify:track:2AMTKKLUWnzxITCgraSErk': 0,
#  'spotify:track:0WscMmqHQLWjqNaGhdoEJa': 0,
#  'spotify:track:6jo5YKDYHDZ2dWErUube93': 0,
#  'spotify:track:6DoPRzpImXp3zffMVCOVlk': 0,
#  'spotify:track:76WDKqn8Tz6EBDApvIOzdk': 0,
#  'spotify:track:6fp8Szw9Ryle5DNIgoCGLd': 0,
#  'spotify:track:3kyREwAYRDTtHEDC5Woco5': 0,
#  'spotify:track:3JocwcYaDJido04ppyLxaI': 0,
#  'spotify:track:1LvcpeOiBhOk0uVuDzSWrW': 0,
#  'spotify:track:2N81uRRfEiHwjKkOmrGFkb': 0,
#  'spotify:track:4ey7m8qxk7QYgG6u6cku2N': 0,
#  'spotify:track:7lYbikUXLOLZrxaKGL6LrB': 0,
#  'spotify:track:4rITWbxUP7ZzaZFioj8PiD': 0,
#  'spotify:track:2CXYKwYc53AfyBilxWmzX8': 0,
#  'spotify:track:7K4uyUh53wGiHPRpVp68TQ': 0,
#  'spotify:track:3FOxQ6UYJOmJ1ynG17lw8V': 0,
#  'spotify:track:42tc0XDBbJ21WbTk2NYefF': 0,
#  'spotify:track:52BBNFnIF20dzifxPWMWhB': 0,
#  'spotify:track:2TYjJt4DoaNMyoglkcTRBC': 0,
#  'spotify:track:4EduC8PcQzSxe4ZQARxvly': 0,
#  'spotify:track:6n87TNgxe2Xc1ym0eI1ure': 0,
#  'spotify:track:6VL8CcFIupoA2VBt4GDoGv': 0,
#  'spotify:track:4MXmqG0Fw3JQExaUkm5SUG': 0,
#  'spotify:track:0Qf4ZNkZ6Ji1SBSI0F8zic': 0,
#  'spotify:track:4TlwaeZSmUBYysbVMFQE3C': 0,
#  'spotify:track:0MJMFa8aqX8n0nnrr8vXCS': 0,
#  'spotify:track:0MejpZ8hTySHWXHVN05FfY': 0,
#  'spotify:track:69yE25vj3tX4TeHIGxk4h8': 0,
#  'spotify:track:5PyxrtLvn8zZjlcZsazojk': 0,
#  'spotify:track:6DXyxxzwsDaug067O3tgyh': 0,
#  'spotify:track:3Hus8WdkhupULK0PE7zj3x': 0,
#  'spotify:track:4mWgQJUspZBORoXhM4OAgb': 0,
#  'spotify:track:20k8NA9OXtIp5AXvWvbjz6': 0,
#  'spotify:track:4OyYIn4wVUs85Qx0VjLLub': 0,
#  'spotify:track:1GngfdyXmpfarEZYoFdOy9': 0,
#  'spotify:track:4Lf0W2IVLVcU6MxR45AD27': 0,
#  'spotify:track:2iZXMKa6Q4GBngBuRWtUtm': 0,
#  'spotify:track:4O0UPAGXfeAK8vM4OUEBFD': 0,
#  'spotify:track:6D6vEVEFVFgctwocglYBLa': 0,
#  'spotify:track:4IG7IRfkbeLBGaQLGWwNPS': 0,
#  'spotify:track:3VRlGstWC0t6Ud5zHNVMub': 0,
#  'spotify:track:5kByEMxRl16QyWFd1VfKzM': 0,
#  'spotify:track:2xB6w6kDh6tDysIaxCnQiI': 0,
#  'spotify:track:11UEWCFpS2gs8DC133vXdT': 0,
#  'spotify:track:0MR3iEiHV5AF8O0iAB84gY': 0,
#  'spotify:track:4CiJAAlUyHFOW4FeiPttvZ': 0,
#  'spotify:track:0nLTye6Iw0ufAxzwbAwzlk': 0,
#  'spotify:track:5mmYqGHaeew6uLxJi5TESh': 0,
#  'spotify:track:41kNXS7D4qIpWK4THCnAOR': 0,
#  'spotify:track:6OKtVfaZ6G0xSbYHh2BfRo': 0,
#  'spotify:track:2PyO0OpZ4tR8xbhzzZs2Ug': 0,
#  'spotify:track:2UyZTPrWFSMysY9cVVjmaB': 0,
#  'spotify:track:0zDu21d7aHrScpTHXRddNr': 0,
#  'spotify:track:0IcL9jPFBst0l7vUcuYVH3': 0,
#  'spotify:track:1CSjnpL63KuOa0VnF6T3uS': 0,
#  'spotify:track:4n2G1Wxz1gYxe7AhYV7N9E': 0,
#  'spotify:track:5vdNoFezjTsQTrZxPK8tDg': 0,
#  'spotify:track:00RI7b6oZDjx6IQC2eH6bh': 0,
#  'spotify:track:3kqiWz1UAgofpKdz3ud4qH': 0,
#  'spotify:track:2mZJnlBZnv4qNN3CH980us': 0,
#  'spotify:track:0FNLnZRNWEIbGsb8jkU2lv': 0,
#  'spotify:track:274tSPavv09i163nBnYrCU': 0,
#  'spotify:track:2wLqxR1CZ8oem1vQ93PXn3': 0,
#  'spotify:track:3As6sADicSuc50rlalhxQa': 0,
#  'spotify:track:1vkdwNTgBAzWFApCVYX9ER': 0,
#  'spotify:track:4djnw5Fd9KSs718VXHXfmL': 0,
#  'spotify:track:78ZsfJB762SXFfLK96mBmC': 0,
#  'spotify:track:63L9AjBDN3SOMbJlBkFqiZ': 0,
#  'spotify:track:7hInOqJnlEayXao08yVYAn': 0,
#  'spotify:track:1a9YW7fATU351ok4zWjU7a': 0,
#  'spotify:track:0q99swv2f9L5m8JHkF3sDC': 0,
#  'spotify:track:2F9JloTNvfkIvwXJP0bZUO': 0,
#  'spotify:track:3mzV0WDATjcpzcTNK2TLJw': 0,
#  'spotify:track:0ZgpvjwRIwTEUkDPWHhTE3': 0,
#  'spotify:track:2VYqkb77OjToeRAnMNd4yU': 0,
#  'spotify:track:1Bv3h7Vc4AaYA2BcSM3rVd': 0,
#  'spotify:track:6Slaf2WBzQA86oS7MNMUNS': 0,
#  'spotify:track:1dWXQWIjjYWafYgw0zVGnG': 0,
#  'spotify:track:5IDmJ2xMwIUkSTPgGcgi3D': 0,
#  'spotify:track:0xQvrfyrolYl97XYPwzvgp': 0,
#  'spotify:track:5SXOjY47VSzmS3vnPXTSr9': 0,
#  'spotify:track:3cS6YsU197mrdPTyR7nbp7': 0,
#  'spotify:track:693RS5ZwxIB6uq0tH7KWRB': 0,
#  'spotify:track:1bNyqXSYpukBLB1A11jyCY': 0,
#  'spotify:track:23OKrAgGOUAv5Sr2kYktaA': 0,
#  'spotify:track:568ttZHRiVUUAR3wUY2Y7O': 0,
#  'spotify:track:1TVHqlYQPZuVHNxSNTw8qd': 0,
#  'spotify:track:2FqosNGYTFddG0Ev62wKEa': 0,
#  'spotify:track:22YmOvOuju6Ugimqg4u7zt': 0,
#  'spotify:track:5180JY8ottJGHaMRnrsoqf': 0,
#  'spotify:track:5WXIBx21pd7zJscPGd8ZaT': 0,
#  'spotify:track:3BhctwMUY5Y9xmes194QTq': 0,
#  'spotify:track:4yifRjkTayXblqdKm0lza5': 0,
#  'spotify:track:2N1ksfnRHLmKlTNHwuaGvF': 0,
#  'spotify:track:2wmY09fsvmYgA7bKZzjAVt': 0,
#  'spotify:track:5TgKL1E0DxD7zG1Ztcz5Sy': 0,
#  'spotify:track:3QhJAGDdxt749dFveYVy4M': 0,
#  'spotify:track:2SrahozuIn33Wacjfgw0qW': 0,
#  'spotify:track:5gj5jumGXCfJV18XpojMMY': 0,
#  'spotify:track:3lBlDJgk1YpzBaTPexTN8m': 0,
#  'spotify:track:10Vwv1zMKjS74NNJEcTteR': 0,
#  'spotify:track:7mL4nN1f2e640JKlvqgXmD': 0,
#  'spotify:track:7m71ZPxAGhSRDyUST1GExn': 0,
#  'spotify:track:2oQTYyJpTBlpyUlQHPrw8l': 0,
#  'spotify:track:3t3P8sFsenZgM2pSufAO9K': 0,
#  'spotify:track:1hFhXWJzLDfIphNrphYnHi': 0,
#  'spotify:track:4P76CEIXrrWT2cgS1YrTMr': 0,
#  'spotify:track:2OWKDTonST8HNko3dBlPPp': 0,
#  'spotify:track:5eTNdkstwKaNahHf41fJ9u': 0,
#  'spotify:track:1mxaufUe16G9wOoG9ptUqr': 0,
#  'spotify:track:0mDGNetRxywxqgiXFbagZh': 0,
#  'spotify:track:0gtSPYz0OHoF7k09Auq1uC': 0,
#  'spotify:track:4wNQAG2BzbVkLhdajjxGpR': 0,
#  'spotify:track:5E5MqaS6eOsbaJibl3YeMZ': 0,
#  'spotify:track:2qxagPKgS2Wc05MLmJucBE': 0,
#  'spotify:track:4isCUHcZJs0o8niODly6qc': 0,
#  'spotify:track:2qES7NEo0DCDvi707VS3HC': 0,
#  'spotify:track:0LwbO2KIQw1uR2FCqwaKAu': 0,
#  'spotify:track:1oXHXIB8rHgwHSsPRNjEzn': 0,
#  'spotify:track:3RPMYxTNEDTG8SZvH3FaVY': 0,
#  'spotify:track:4L64frXCQBioY6oWAhCT0w': 0,
#  'spotify:track:5YTzmYWaMCnSBtCodjtxn7': 0,
#  'spotify:track:0MHbaWa5CGNa7bdJb0rX46': 0,
#  'spotify:track:5h27GYpKZWWhFov8fOunF6': 0,
#  'spotify:track:5mOPeaSXywGZX3mDflbDsq': 0,
#  'spotify:track:1dawtCVI1A3nYxJX32lBH2': 0,
#  'spotify:track:08FGTSIe1HZ0WpdxD95ESy': 0,
#  'spotify:track:1fn1RZO7oiEmLm1MIGLb27': 0,
#  'spotify:track:0ZRpZMW2kl3b52w9dn2oUM': 0,
#  'spotify:track:55H7cdGXn6670EiHiTuOtU': 0,
#  'spotify:track:7BXoTlwSu8FwgsNs4RjDGM': 0,
#  'spotify:track:66IHpS7V8P8jaWQR7yfTyj': 0,
#  'spotify:track:58BsYHaWdK78SIZMWztmC3': 0,
#  'spotify:track:5pVSOZVIWaRxF0zhjlnEUy': 0,
#  'spotify:track:0W1M8vt5AoAidBEah3NE0H': 0,
#  'spotify:track:1nc3cMQQoA6uOGgIrGjBIa': 0,
#  'spotify:track:3oqJ3POeLfa2TJh6BFLhPM': 0,
#  'spotify:track:1FKWWmT46hgeerUUR7YedM': 0,
#  'spotify:track:2nqMzaaRiinfR2B4egiHgI': 0,
#  'spotify:track:4xljyiFc4EyztCfwNxs5ur': 0,
#  'spotify:track:0sk9SQJ17g7eUzJ2ObjKwR': 0,
#  'spotify:track:6ShMtou6pfX6E18iqsBAc7': 0,
#  'spotify:track:3yGCPtAaLOZjNBNFt80GFA': 0,
#  'spotify:track:5umI2Ra11zPhee5ShYXps2': 0,
#  'spotify:track:2XBAkFYQyVNnwhGQVNxQKZ': 0,
#  'spotify:track:4R9KztunyNTH13KtAqePLp': 0,
#  'spotify:track:5tlu2nA8GxkDx8UTKG1rLV': 0,
#  'spotify:track:7cRw4UbtGEwGIRgYimPQM7': 0,
#  'spotify:track:0xTcz4CIGTvPaBeqVhXxo1': 0,
#  'spotify:track:6Mim9UiRx267U52L1zqD0Q': 0,
#  'spotify:track:1X02d1tRJSYPoLzZNy9hFJ': 0,
#  'spotify:track:2IxOGK5JJIhi2Alx5BA7oe': 0,
#  'spotify:track:3X8p1YDdZmvVYwHq0e5oYQ': 0,
#  'spotify:track:7AoYZaUW8cj6LaDmg48QLU': 0,
#  'spotify:track:33pOksMV4ZiBBaeEEswQV0': 0,
#  'spotify:track:2i8nLoRrUgY0zVtsDxCooV': 0,
#  'spotify:track:6U6GxNSwLzAWH8AHQysgma': 0,
#  'spotify:track:6CZcz3Z0CgqxAsKLl8SVbL': 0,
#  'spotify:track:4i3Lyj3mNZmtVjbNiqmBLE': 0,
#  'spotify:track:14xBemGXjFZ0kSVzhscVAi': 0,
#  'spotify:track:4D8TEFxhJvApwuGQ9vVkni': 0,
#  'spotify:track:6IGSaexMeb4LPcTuGkFp5m': 0,
#  'spotify:track:0y8DOpEKqm733hFvy2V2MM': 0,
#  'spotify:track:44g6Z7TWrKbaZVJJpV8ClH': 0,
#  'spotify:track:319uuqvcaGuLM1pOpWSwyx': 0,
#  'spotify:track:1RHTE7ptVWJIEleCt5KeeN': 0,
#  'spotify:track:3WtiuySeEpxkElpsguTAfb': 0,
#  'spotify:track:2yEe3VwrFxODcUjwOzOxce': 0,
#  'spotify:track:1vF1mxAY1WMXkwX2DLUymp': 0,
#  'spotify:track:7s5HG3HDsJ7oULEdPNI3j8': 0,
#  'spotify:track:7BMaph2YZr49SQynfQWyCv': 0,
#  'spotify:track:0LsbECeAkJlpI0abEW79oF': 0,
#  'spotify:track:4Fp6CGsVJBPpFgngT71TxW': 0,
#  'spotify:track:4rRFrRB6qzZ2eB04oTJVLr': 0,
#  'spotify:track:04NNFxjRAtH8s8HBYwliXr': 0,
#  'spotify:track:58jixBsgitPoKXQgxcDsu2': 0,
#  'spotify:track:6rkZ2wgpDuD3hSTRHX53kT': 0,
#  'spotify:track:6xxzyJdP6FX1LG9YsrNBvN': 0,
#  'spotify:track:395hQeMro7XqMW4YhcayzK': 0,
#  'spotify:track:4BC2UkwIvIatnuSF36o6uI': 0,
#  'spotify:track:6RRsYGHCM794ZS7HfmBL0z': 0,
#  'spotify:track:2HDAqP6SKFsFIz00BPMuE9': 0,
#  'spotify:track:0vLryAFXfk6CE4Xyt0rg2S': 0,
#  ...}
